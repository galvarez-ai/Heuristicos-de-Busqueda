# %%
import numpy as np

# %%
class PSO_Exam:
    def __init__(self, n_particles=50, n_dim=10, max_evals=100000):
        self.n_particles = n_particles
        self.n_dim = n_dim
        self.max_evals = max_evals
        
        # --- 1. INICIALIZACIÓN ---
        # Rango [-5.12, 5.12]
        self.X = np.random.uniform(-5.12, 5.12, (n_particles, n_dim))
        # Velocidad inicial pequeña (ceros o random pequeño)
        self.V = np.random.randn(n_particles, n_dim) * 0.1
        
        # --- 2. MEMORIA (pBest y gBest) ---
        # Mejor posición personal (pBest): Al principio es la actual
        self.pBest_pos = self.X.copy()
        # Mejor nota personal: Al principio es la actual
        self.pBest_val = np.array([self.get_fitness(ind) for ind in self.X])
        
        # Mejor global (gBest): El mejor de los personales
        best_idx = np.argmin(self.pBest_val)
        self.gBest_pos = self.pBest_pos[best_idx].copy()
        self.gBest_val = self.pBest_val[best_idx]
        
        # Hiperparámetros del enunciado
        self.w = 0.7  # Inercia
        self.c1 = 1.5 # Cognitivo
        self.c2 = 1.5 # Social

    def get_fitness(self, particle):
        """
        Función Sphere: Suma de cuadrados.
        Recibe un array (10,) y devuelve un float.
        """
        return np.sum(particle**2)

    def update_particles(self):
        """
        El Motor Físico: Mueve todo el enjambre a la vez usando matrices.
        """
        # Generamos aleatorios (r1, r2) para TODAS las coordenadas de golpe
        r1 = np.random.rand(self.n_particles, self.n_dim)
        r2 = np.random.rand(self.n_particles, self.n_dim)
        
        # --- FÓRMULA DE VELOCIDAD (Vectorizada) ---
        # v_new = w*v + c1*r1*(pBest - X) + c2*r2*(gBest - X)
        inertia = self.w * self.V
        cognitive = self.c1 * r1 * (self.pBest_pos - self.X)
        social = self.c2 * r2 * (self.gBest_pos - self.X) # Numpy resta vector gBest a cada fila de X
        
        self.V = inertia + cognitive + social
        
        # --- FÓRMULA DE POSICIÓN ---
        self.X = self.X + self.V
        
        # Opcional: Limitar al rango (rebotar o clippear) para no salir del mapa
        self.X = np.clip(self.X, -5.12, 5.12)

    def run(self):
        evals = 0
        iteration = 0
        
        # Como evaluamos 50 partículas por ciclo, avanzamos de 50 en 50
        while evals < self.max_evals:
            iteration += 1
            
            # 1. MOVER ENJAMBRE
            self.update_particles()
            
            # 2. EVALUAR Y ACTUALIZAR MEMORIA
            # Calculamos fitness de las nuevas posiciones
            # (Vectorizado: aplicamos la función a cada fila)
            current_fitness_values = np.array([self.get_fitness(p) for p in self.X])
            evals += self.n_particles
            
            # 3. ACTUALIZAR pBest (Personal)
            # Buscamos dónde hemos mejorado (máscara booleana)
            improved_indices = current_fitness_values < self.pBest_val
            
            # Actualizamos solo donde hubo mejora
            self.pBest_pos[improved_indices] = self.X[improved_indices]
            self.pBest_val[improved_indices] = current_fitness_values[improved_indices]
            
            # 4. ACTUALIZAR gBest (Global)
            # Miramos si alguien de la nueva generación ha superado el récord mundial
            min_val_iter = np.min(self.pBest_val)
            min_idx_iter = np.argmin(self.pBest_val)
            
            if min_val_iter < self.gBest_val:
                self.gBest_val = min_val_iter
                self.gBest_pos = self.pBest_pos[min_idx_iter].copy()
                print(f"Iter {iteration} (Evals {evals}): Nuevo Récord Global -> {self.gBest_val:.10f}")
                
        return self.gBest_val

# --- TEST DEL EXAMEN ---
pso_solver = PSO_Exam()
resultado = pso_solver.run()
print(f"\nResultado final (debe ser cercano a 0): {resultado}")
# Out:
# Iter 1 (Evals 50): Nuevo Récord Global -> 14.9036228420
# Iter 2 (Evals 100): Nuevo Récord Global -> 13.0658023620
# Iter 3 (Evals 150): Nuevo Récord Global -> 11.2388340435
# Iter 5 (Evals 250): Nuevo Récord Global -> 7.6774060288
# Iter 6 (Evals 300): Nuevo Récord Global -> 6.0161215888
# Iter 7 (Evals 350): Nuevo Récord Global -> 3.9509996625
# Iter 8 (Evals 400): Nuevo Récord Global -> 1.5446306368
# Iter 9 (Evals 450): Nuevo Récord Global -> 1.5042438366
# Iter 11 (Evals 550): Nuevo Récord Global -> 1.3668676266
# Iter 13 (Evals 650): Nuevo Récord Global -> 1.3270299499
# Iter 15 (Evals 750): Nuevo Récord Global -> 0.9677508472
# Iter 16 (Evals 800): Nuevo Récord Global -> 0.6983232995
# Iter 21 (Evals 1050): Nuevo Récord Global -> 0.5651765305
# Iter 22 (Evals 1100): Nuevo Récord Global -> 0.4088174951
# Iter 23 (Evals 1150): Nuevo Récord Global -> 0.1967915343
# Iter 24 (Evals 1200): Nuevo Récord Global -> 0.1795922476
# Iter 28 (Evals 1400): Nuevo Récord Global -> 0.1171850144
# Iter 30 (Evals 1500): Nuevo Récord Global -> 0.0729433018
# Iter 31 (Evals 1550): Nuevo Récord Global -> 0.0686202664
# Iter 34 (Evals 1700): Nuevo Récord Global -> 0.0373772477
# Iter 36 (Evals 1800): Nuevo Récord Global -> 0.0274076135
# Iter 37 (Evals 1850): Nuevo Récord Global -> 0.0247279231
# Iter 38 (Evals 1900): Nuevo Récord Global -> 0.0212649152
# Iter 40 (Evals 2000): Nuevo Récord Global -> 0.0182928480
# Iter 43 (Evals 2150): Nuevo Récord Global -> 0.0175793904
# Iter 45 (Evals 2250): Nuevo Récord Global -> 0.0124211326
# Iter 46 (Evals 2300): Nuevo Récord Global -> 0.0055175285
# Iter 48 (Evals 2400): Nuevo Récord Global -> 0.0029071131
# Iter 55 (Evals 2750): Nuevo Récord Global -> 0.0026647999
# Iter 56 (Evals 2800): Nuevo Récord Global -> 0.0025164617
# Iter 57 (Evals 2850): Nuevo Récord Global -> 0.0024722575
# Iter 58 (Evals 2900): Nuevo Récord Global -> 0.0020792229
# Iter 59 (Evals 2950): Nuevo Récord Global -> 0.0007742109
# Iter 62 (Evals 3100): Nuevo Récord Global -> 0.0004045527
# Iter 64 (Evals 3200): Nuevo Récord Global -> 0.0002372412
# Iter 69 (Evals 3450): Nuevo Récord Global -> 0.0001786208
# Iter 72 (Evals 3600): Nuevo Récord Global -> 0.0001604255
# Iter 74 (Evals 3700): Nuevo Récord Global -> 0.0001081424
# Iter 77 (Evals 3850): Nuevo Récord Global -> 0.0000910008
# Iter 78 (Evals 3900): Nuevo Récord Global -> 0.0000756493
# Iter 81 (Evals 4050): Nuevo Récord Global -> 0.0000672729
# Iter 82 (Evals 4100): Nuevo Récord Global -> 0.0000429343
# Iter 83 (Evals 4150): Nuevo Récord Global -> 0.0000283183
# Iter 86 (Evals 4300): Nuevo Récord Global -> 0.0000190215
# Iter 88 (Evals 4400): Nuevo Récord Global -> 0.0000126278
# Iter 89 (Evals 4450): Nuevo Récord Global -> 0.0000099547
# Iter 90 (Evals 4500): Nuevo Récord Global -> 0.0000096559
# Iter 91 (Evals 4550): Nuevo Récord Global -> 0.0000072917
# Iter 93 (Evals 4650): Nuevo Récord Global -> 0.0000071905
# Iter 94 (Evals 4700): Nuevo Récord Global -> 0.0000065579
# Iter 95 (Evals 4750): Nuevo Récord Global -> 0.0000040500
# Iter 97 (Evals 4850): Nuevo Récord Global -> 0.0000033146
# Iter 99 (Evals 4950): Nuevo Récord Global -> 0.0000027111
# Iter 100 (Evals 5000): Nuevo Récord Global -> 0.0000022262
# Iter 101 (Evals 5050): Nuevo Récord Global -> 0.0000018561
# Iter 106 (Evals 5300): Nuevo Récord Global -> 0.0000012819
# Iter 107 (Evals 5350): Nuevo Récord Global -> 0.0000008491
# Iter 108 (Evals 5400): Nuevo Récord Global -> 0.0000004895
# Iter 115 (Evals 5750): Nuevo Récord Global -> 0.0000003538
# Iter 117 (Evals 5850): Nuevo Récord Global -> 0.0000002286
# Iter 119 (Evals 5950): Nuevo Récord Global -> 0.0000001811
# Iter 121 (Evals 6050): Nuevo Récord Global -> 0.0000001578
# Iter 123 (Evals 6150): Nuevo Récord Global -> 0.0000001216
# Iter 124 (Evals 6200): Nuevo Récord Global -> 0.0000000805
# Iter 126 (Evals 6300): Nuevo Récord Global -> 0.0000000639
# Iter 127 (Evals 6350): Nuevo Récord Global -> 0.0000000574
# Iter 130 (Evals 6500): Nuevo Récord Global -> 0.0000000495
# Iter 131 (Evals 6550): Nuevo Récord Global -> 0.0000000453
# Iter 132 (Evals 6600): Nuevo Récord Global -> 0.0000000170
# Iter 137 (Evals 6850): Nuevo Récord Global -> 0.0000000141
# Iter 138 (Evals 6900): Nuevo Récord Global -> 0.0000000113
# Iter 139 (Evals 6950): Nuevo Récord Global -> 0.0000000103
# Iter 140 (Evals 7000): Nuevo Récord Global -> 0.0000000102
# Iter 141 (Evals 7050): Nuevo Récord Global -> 0.0000000093
# Iter 142 (Evals 7100): Nuevo Récord Global -> 0.0000000070
# Iter 143 (Evals 7150): Nuevo Récord Global -> 0.0000000054
# Iter 145 (Evals 7250): Nuevo Récord Global -> 0.0000000050
# Iter 146 (Evals 7300): Nuevo Récord Global -> 0.0000000046
# Iter 147 (Evals 7350): Nuevo Récord Global -> 0.0000000033
# Iter 148 (Evals 7400): Nuevo Récord Global -> 0.0000000031
# Iter 149 (Evals 7450): Nuevo Récord Global -> 0.0000000019
# Iter 150 (Evals 7500): Nuevo Récord Global -> 0.0000000007
# Iter 153 (Evals 7650): Nuevo Récord Global -> 0.0000000003
# Iter 155 (Evals 7750): Nuevo Récord Global -> 0.0000000003
# Iter 157 (Evals 7850): Nuevo Récord Global -> 0.0000000002
# Iter 160 (Evals 8000): Nuevo Récord Global -> 0.0000000001
# Iter 163 (Evals 8150): Nuevo Récord Global -> 0.0000000001
# Iter 165 (Evals 8250): Nuevo Récord Global -> 0.0000000000
# Iter 171 (Evals 8550): Nuevo Récord Global -> 0.0000000000
# Iter 176 (Evals 8800): Nuevo Récord Global -> 0.0000000000
# Iter 180 (Evals 9000): Nuevo Récord Global -> 0.0000000000
# Iter 183 (Evals 9150): Nuevo Récord Global -> 0.0000000000
# Iter 186 (Evals 9300): Nuevo Récord Global -> 0.0000000000
# Iter 188 (Evals 9400): Nuevo Récord Global -> 0.0000000000
# Iter 190 (Evals 9500): Nuevo Récord Global -> 0.0000000000
# Iter 191 (Evals 9550): Nuevo Récord Global -> 0.0000000000
# Iter 194 (Evals 9700): Nuevo Récord Global -> 0.0000000000
# Iter 198 (Evals 9900): Nuevo Récord Global -> 0.0000000000
# Iter 199 (Evals 9950): Nuevo Récord Global -> 0.0000000000
# Iter 202 (Evals 10100): Nuevo Récord Global -> 0.0000000000
# Iter 204 (Evals 10200): Nuevo Récord Global -> 0.0000000000
# Iter 206 (Evals 10300): Nuevo Récord Global -> 0.0000000000
# Iter 208 (Evals 10400): Nuevo Récord Global -> 0.0000000000
# Iter 209 (Evals 10450): Nuevo Récord Global -> 0.0000000000
# Iter 210 (Evals 10500): Nuevo Récord Global -> 0.0000000000
# Iter 211 (Evals 10550): Nuevo Récord Global -> 0.0000000000
# Iter 214 (Evals 10700): Nuevo Récord Global -> 0.0000000000
# Iter 215 (Evals 10750): Nuevo Récord Global -> 0.0000000000
# Iter 216 (Evals 10800): Nuevo Récord Global -> 0.0000000000
# Iter 217 (Evals 10850): Nuevo Récord Global -> 0.0000000000
# Iter 218 (Evals 10900): Nuevo Récord Global -> 0.0000000000
# Iter 220 (Evals 11000): Nuevo Récord Global -> 0.0000000000
# Iter 221 (Evals 11050): Nuevo Récord Global -> 0.0000000000
# Iter 224 (Evals 11200): Nuevo Récord Global -> 0.0000000000
# Iter 226 (Evals 11300): Nuevo Récord Global -> 0.0000000000
# Iter 228 (Evals 11400): Nuevo Récord Global -> 0.0000000000
# Iter 230 (Evals 11500): Nuevo Récord Global -> 0.0000000000
# Iter 231 (Evals 11550): Nuevo Récord Global -> 0.0000000000
# Iter 232 (Evals 11600): Nuevo Récord Global -> 0.0000000000
# Iter 233 (Evals 11650): Nuevo Récord Global -> 0.0000000000
# Iter 234 (Evals 11700): Nuevo Récord Global -> 0.0000000000
# Iter 240 (Evals 12000): Nuevo Récord Global -> 0.0000000000
# Iter 243 (Evals 12150): Nuevo Récord Global -> 0.0000000000
# Iter 244 (Evals 12200): Nuevo Récord Global -> 0.0000000000
# Iter 248 (Evals 12400): Nuevo Récord Global -> 0.0000000000
# Iter 251 (Evals 12550): Nuevo Récord Global -> 0.0000000000
# Iter 254 (Evals 12700): Nuevo Récord Global -> 0.0000000000
# Iter 256 (Evals 12800): Nuevo Récord Global -> 0.0000000000
# Iter 258 (Evals 12900): Nuevo Récord Global -> 0.0000000000
# Iter 260 (Evals 13000): Nuevo Récord Global -> 0.0000000000
# Iter 261 (Evals 13050): Nuevo Récord Global -> 0.0000000000
# Iter 265 (Evals 13250): Nuevo Récord Global -> 0.0000000000
# Iter 268 (Evals 13400): Nuevo Récord Global -> 0.0000000000
# Iter 272 (Evals 13600): Nuevo Récord Global -> 0.0000000000
# Iter 273 (Evals 13650): Nuevo Récord Global -> 0.0000000000
# Iter 275 (Evals 13750): Nuevo Récord Global -> 0.0000000000
# Iter 277 (Evals 13850): Nuevo Récord Global -> 0.0000000000
# Iter 278 (Evals 13900): Nuevo Récord Global -> 0.0000000000
# Iter 280 (Evals 14000): Nuevo Récord Global -> 0.0000000000
# Iter 282 (Evals 14100): Nuevo Récord Global -> 0.0000000000
# Iter 286 (Evals 14300): Nuevo Récord Global -> 0.0000000000
# Iter 288 (Evals 14400): Nuevo Récord Global -> 0.0000000000
# Iter 289 (Evals 14450): Nuevo Récord Global -> 0.0000000000
# Iter 290 (Evals 14500): Nuevo Récord Global -> 0.0000000000
# Iter 291 (Evals 14550): Nuevo Récord Global -> 0.0000000000
# Iter 294 (Evals 14700): Nuevo Récord Global -> 0.0000000000
# Iter 295 (Evals 14750): Nuevo Récord Global -> 0.0000000000
# Iter 300 (Evals 15000): Nuevo Récord Global -> 0.0000000000
# Iter 301 (Evals 15050): Nuevo Récord Global -> 0.0000000000
# Iter 302 (Evals 15100): Nuevo Récord Global -> 0.0000000000
# Iter 307 (Evals 15350): Nuevo Récord Global -> 0.0000000000
# Iter 308 (Evals 15400): Nuevo Récord Global -> 0.0000000000
# Iter 309 (Evals 15450): Nuevo Récord Global -> 0.0000000000
# Iter 311 (Evals 15550): Nuevo Récord Global -> 0.0000000000
# Iter 313 (Evals 15650): Nuevo Récord Global -> 0.0000000000
# Iter 314 (Evals 15700): Nuevo Récord Global -> 0.0000000000
# Iter 317 (Evals 15850): Nuevo Récord Global -> 0.0000000000
# Iter 318 (Evals 15900): Nuevo Récord Global -> 0.0000000000
# Iter 319 (Evals 15950): Nuevo Récord Global -> 0.0000000000
# Iter 320 (Evals 16000): Nuevo Récord Global -> 0.0000000000
# Iter 323 (Evals 16150): Nuevo Récord Global -> 0.0000000000
# Iter 324 (Evals 16200): Nuevo Récord Global -> 0.0000000000
# Iter 325 (Evals 16250): Nuevo Récord Global -> 0.0000000000
# Iter 326 (Evals 16300): Nuevo Récord Global -> 0.0000000000
# Iter 327 (Evals 16350): Nuevo Récord Global -> 0.0000000000
# Iter 330 (Evals 16500): Nuevo Récord Global -> 0.0000000000
# Iter 331 (Evals 16550): Nuevo Récord Global -> 0.0000000000
# Iter 334 (Evals 16700): Nuevo Récord Global -> 0.0000000000
# Iter 337 (Evals 16850): Nuevo Récord Global -> 0.0000000000
# Iter 339 (Evals 16950): Nuevo Récord Global -> 0.0000000000
# Iter 343 (Evals 17150): Nuevo Récord Global -> 0.0000000000
# Iter 344 (Evals 17200): Nuevo Récord Global -> 0.0000000000
# Iter 346 (Evals 17300): Nuevo Récord Global -> 0.0000000000
# Iter 348 (Evals 17400): Nuevo Récord Global -> 0.0000000000
# Iter 350 (Evals 17500): Nuevo Récord Global -> 0.0000000000
# Iter 355 (Evals 17750): Nuevo Récord Global -> 0.0000000000
# Iter 356 (Evals 17800): Nuevo Récord Global -> 0.0000000000
# Iter 357 (Evals 17850): Nuevo Récord Global -> 0.0000000000
# Iter 358 (Evals 17900): Nuevo Récord Global -> 0.0000000000
# Iter 359 (Evals 17950): Nuevo Récord Global -> 0.0000000000
# Iter 362 (Evals 18100): Nuevo Récord Global -> 0.0000000000
# Iter 364 (Evals 18200): Nuevo Récord Global -> 0.0000000000
# Iter 366 (Evals 18300): Nuevo Récord Global -> 0.0000000000
# Iter 367 (Evals 18350): Nuevo Récord Global -> 0.0000000000
# Iter 369 (Evals 18450): Nuevo Récord Global -> 0.0000000000
# Iter 371 (Evals 18550): Nuevo Récord Global -> 0.0000000000
# Iter 374 (Evals 18700): Nuevo Récord Global -> 0.0000000000
# Iter 375 (Evals 18750): Nuevo Récord Global -> 0.0000000000
# Iter 378 (Evals 18900): Nuevo Récord Global -> 0.0000000000
# Iter 380 (Evals 19000): Nuevo Récord Global -> 0.0000000000
# Iter 381 (Evals 19050): Nuevo Récord Global -> 0.0000000000
# Iter 383 (Evals 19150): Nuevo Récord Global -> 0.0000000000
# Iter 384 (Evals 19200): Nuevo Récord Global -> 0.0000000000
# Iter 386 (Evals 19300): Nuevo Récord Global -> 0.0000000000
# Iter 388 (Evals 19400): Nuevo Récord Global -> 0.0000000000
# Iter 389 (Evals 19450): Nuevo Récord Global -> 0.0000000000
# Iter 390 (Evals 19500): Nuevo Récord Global -> 0.0000000000
# Iter 391 (Evals 19550): Nuevo Récord Global -> 0.0000000000
# Iter 393 (Evals 19650): Nuevo Récord Global -> 0.0000000000
# Iter 394 (Evals 19700): Nuevo Récord Global -> 0.0000000000
# Iter 397 (Evals 19850): Nuevo Récord Global -> 0.0000000000
# Iter 398 (Evals 19900): Nuevo Récord Global -> 0.0000000000
# Iter 399 (Evals 19950): Nuevo Récord Global -> 0.0000000000
# Iter 402 (Evals 20100): Nuevo Récord Global -> 0.0000000000
# Iter 403 (Evals 20150): Nuevo Récord Global -> 0.0000000000
# Iter 405 (Evals 20250): Nuevo Récord Global -> 0.0000000000
# Iter 406 (Evals 20300): Nuevo Récord Global -> 0.0000000000
# Iter 407 (Evals 20350): Nuevo Récord Global -> 0.0000000000
# Iter 408 (Evals 20400): Nuevo Récord Global -> 0.0000000000
# Iter 409 (Evals 20450): Nuevo Récord Global -> 0.0000000000
# Iter 410 (Evals 20500): Nuevo Récord Global -> 0.0000000000
# Iter 411 (Evals 20550): Nuevo Récord Global -> 0.0000000000
# Iter 412 (Evals 20600): Nuevo Récord Global -> 0.0000000000
# Iter 414 (Evals 20700): Nuevo Récord Global -> 0.0000000000
# Iter 417 (Evals 20850): Nuevo Récord Global -> 0.0000000000
# Iter 419 (Evals 20950): Nuevo Récord Global -> 0.0000000000
# Iter 420 (Evals 21000): Nuevo Récord Global -> 0.0000000000
# Iter 421 (Evals 21050): Nuevo Récord Global -> 0.0000000000
# Iter 424 (Evals 21200): Nuevo Récord Global -> 0.0000000000
# Iter 425 (Evals 21250): Nuevo Récord Global -> 0.0000000000
# Iter 427 (Evals 21350): Nuevo Récord Global -> 0.0000000000
# Iter 428 (Evals 21400): Nuevo Récord Global -> 0.0000000000
# Iter 430 (Evals 21500): Nuevo Récord Global -> 0.0000000000
# Iter 432 (Evals 21600): Nuevo Récord Global -> 0.0000000000
# Iter 433 (Evals 21650): Nuevo Récord Global -> 0.0000000000
# Iter 436 (Evals 21800): Nuevo Récord Global -> 0.0000000000
# Iter 438 (Evals 21900): Nuevo Récord Global -> 0.0000000000
# Iter 439 (Evals 21950): Nuevo Récord Global -> 0.0000000000
# Iter 441 (Evals 22050): Nuevo Récord Global -> 0.0000000000
# Iter 446 (Evals 22300): Nuevo Récord Global -> 0.0000000000
# Iter 447 (Evals 22350): Nuevo Récord Global -> 0.0000000000
# Iter 449 (Evals 22450): Nuevo Récord Global -> 0.0000000000
# Iter 450 (Evals 22500): Nuevo Récord Global -> 0.0000000000
# Iter 451 (Evals 22550): Nuevo Récord Global -> 0.0000000000
# Iter 453 (Evals 22650): Nuevo Récord Global -> 0.0000000000
# Iter 456 (Evals 22800): Nuevo Récord Global -> 0.0000000000
# Iter 461 (Evals 23050): Nuevo Récord Global -> 0.0000000000
# Iter 462 (Evals 23100): Nuevo Récord Global -> 0.0000000000
# Iter 464 (Evals 23200): Nuevo Récord Global -> 0.0000000000
# Iter 466 (Evals 23300): Nuevo Récord Global -> 0.0000000000
# Iter 468 (Evals 23400): Nuevo Récord Global -> 0.0000000000
# Iter 469 (Evals 23450): Nuevo Récord Global -> 0.0000000000
# Iter 470 (Evals 23500): Nuevo Récord Global -> 0.0000000000
# Iter 471 (Evals 23550): Nuevo Récord Global -> 0.0000000000
# Iter 472 (Evals 23600): Nuevo Récord Global -> 0.0000000000
# Iter 475 (Evals 23750): Nuevo Récord Global -> 0.0000000000
# Iter 476 (Evals 23800): Nuevo Récord Global -> 0.0000000000
# Iter 478 (Evals 23900): Nuevo Récord Global -> 0.0000000000
# Iter 483 (Evals 24150): Nuevo Récord Global -> 0.0000000000
# Iter 485 (Evals 24250): Nuevo Récord Global -> 0.0000000000
# Iter 486 (Evals 24300): Nuevo Récord Global -> 0.0000000000
# Iter 487 (Evals 24350): Nuevo Récord Global -> 0.0000000000
# Iter 488 (Evals 24400): Nuevo Récord Global -> 0.0000000000
# Iter 490 (Evals 24500): Nuevo Récord Global -> 0.0000000000
# Iter 491 (Evals 24550): Nuevo Récord Global -> 0.0000000000
# Iter 494 (Evals 24700): Nuevo Récord Global -> 0.0000000000
# Iter 495 (Evals 24750): Nuevo Récord Global -> 0.0000000000
# Iter 499 (Evals 24950): Nuevo Récord Global -> 0.0000000000
# Iter 501 (Evals 25050): Nuevo Récord Global -> 0.0000000000
# Iter 502 (Evals 25100): Nuevo Récord Global -> 0.0000000000
# Iter 507 (Evals 25350): Nuevo Récord Global -> 0.0000000000
# Iter 508 (Evals 25400): Nuevo Récord Global -> 0.0000000000
# Iter 509 (Evals 25450): Nuevo Récord Global -> 0.0000000000
# Iter 512 (Evals 25600): Nuevo Récord Global -> 0.0000000000
# Iter 513 (Evals 25650): Nuevo Récord Global -> 0.0000000000
# Iter 514 (Evals 25700): Nuevo Récord Global -> 0.0000000000
# Iter 517 (Evals 25850): Nuevo Récord Global -> 0.0000000000
# Iter 520 (Evals 26000): Nuevo Récord Global -> 0.0000000000
# Iter 521 (Evals 26050): Nuevo Récord Global -> 0.0000000000
# Iter 524 (Evals 26200): Nuevo Récord Global -> 0.0000000000
# Iter 527 (Evals 26350): Nuevo Récord Global -> 0.0000000000
# Iter 529 (Evals 26450): Nuevo Récord Global -> 0.0000000000
# Iter 533 (Evals 26650): Nuevo Récord Global -> 0.0000000000
# Iter 534 (Evals 26700): Nuevo Récord Global -> 0.0000000000
# Iter 537 (Evals 26850): Nuevo Récord Global -> 0.0000000000
# Iter 540 (Evals 27000): Nuevo Récord Global -> 0.0000000000
# Iter 541 (Evals 27050): Nuevo Récord Global -> 0.0000000000
# Iter 542 (Evals 27100): Nuevo Récord Global -> 0.0000000000
# Iter 543 (Evals 27150): Nuevo Récord Global -> 0.0000000000
# Iter 544 (Evals 27200): Nuevo Récord Global -> 0.0000000000
# Iter 547 (Evals 27350): Nuevo Récord Global -> 0.0000000000
# Iter 551 (Evals 27550): Nuevo Récord Global -> 0.0000000000
# Iter 552 (Evals 27600): Nuevo Récord Global -> 0.0000000000
# Iter 555 (Evals 27750): Nuevo Récord Global -> 0.0000000000
# Iter 558 (Evals 27900): Nuevo Récord Global -> 0.0000000000
# Iter 564 (Evals 28200): Nuevo Récord Global -> 0.0000000000
# Iter 565 (Evals 28250): Nuevo Récord Global -> 0.0000000000
# Iter 566 (Evals 28300): Nuevo Récord Global -> 0.0000000000
# Iter 570 (Evals 28500): Nuevo Récord Global -> 0.0000000000
# Iter 571 (Evals 28550): Nuevo Récord Global -> 0.0000000000
# Iter 577 (Evals 28850): Nuevo Récord Global -> 0.0000000000
# Iter 578 (Evals 28900): Nuevo Récord Global -> 0.0000000000
# Iter 580 (Evals 29000): Nuevo Récord Global -> 0.0000000000
# Iter 585 (Evals 29250): Nuevo Récord Global -> 0.0000000000
# Iter 586 (Evals 29300): Nuevo Récord Global -> 0.0000000000
# Iter 587 (Evals 29350): Nuevo Récord Global -> 0.0000000000
# Iter 588 (Evals 29400): Nuevo Récord Global -> 0.0000000000
# Iter 590 (Evals 29500): Nuevo Récord Global -> 0.0000000000
# Iter 592 (Evals 29600): Nuevo Récord Global -> 0.0000000000
# Iter 593 (Evals 29650): Nuevo Récord Global -> 0.0000000000
# Iter 594 (Evals 29700): Nuevo Récord Global -> 0.0000000000
# Iter 595 (Evals 29750): Nuevo Récord Global -> 0.0000000000
# Iter 602 (Evals 30100): Nuevo Récord Global -> 0.0000000000
# Iter 604 (Evals 30200): Nuevo Récord Global -> 0.0000000000
# Iter 608 (Evals 30400): Nuevo Récord Global -> 0.0000000000
# Iter 611 (Evals 30550): Nuevo Récord Global -> 0.0000000000
# Iter 612 (Evals 30600): Nuevo Récord Global -> 0.0000000000
# Iter 613 (Evals 30650): Nuevo Récord Global -> 0.0000000000
# Iter 615 (Evals 30750): Nuevo Récord Global -> 0.0000000000
# Iter 616 (Evals 30800): Nuevo Récord Global -> 0.0000000000
# Iter 617 (Evals 30850): Nuevo Récord Global -> 0.0000000000
# Iter 619 (Evals 30950): Nuevo Récord Global -> 0.0000000000
# Iter 620 (Evals 31000): Nuevo Récord Global -> 0.0000000000
# Iter 621 (Evals 31050): Nuevo Récord Global -> 0.0000000000
# Iter 623 (Evals 31150): Nuevo Récord Global -> 0.0000000000
# Iter 625 (Evals 31250): Nuevo Récord Global -> 0.0000000000
# Iter 627 (Evals 31350): Nuevo Récord Global -> 0.0000000000
# Iter 629 (Evals 31450): Nuevo Récord Global -> 0.0000000000
# Iter 632 (Evals 31600): Nuevo Récord Global -> 0.0000000000
# Iter 633 (Evals 31650): Nuevo Récord Global -> 0.0000000000
# Iter 634 (Evals 31700): Nuevo Récord Global -> 0.0000000000
# Iter 636 (Evals 31800): Nuevo Récord Global -> 0.0000000000
# Iter 637 (Evals 31850): Nuevo Récord Global -> 0.0000000000
# Iter 639 (Evals 31950): Nuevo Récord Global -> 0.0000000000
# Iter 642 (Evals 32100): Nuevo Récord Global -> 0.0000000000
# Iter 644 (Evals 32200): Nuevo Récord Global -> 0.0000000000
# Iter 645 (Evals 32250): Nuevo Récord Global -> 0.0000000000
# Iter 648 (Evals 32400): Nuevo Récord Global -> 0.0000000000
# Iter 651 (Evals 32550): Nuevo Récord Global -> 0.0000000000
# Iter 652 (Evals 32600): Nuevo Récord Global -> 0.0000000000
# Iter 655 (Evals 32750): Nuevo Récord Global -> 0.0000000000
# Iter 656 (Evals 32800): Nuevo Récord Global -> 0.0000000000
# Iter 657 (Evals 32850): Nuevo Récord Global -> 0.0000000000
# Iter 658 (Evals 32900): Nuevo Récord Global -> 0.0000000000
# Iter 660 (Evals 33000): Nuevo Récord Global -> 0.0000000000
# Iter 662 (Evals 33100): Nuevo Récord Global -> 0.0000000000
# Iter 663 (Evals 33150): Nuevo Récord Global -> 0.0000000000
# Iter 665 (Evals 33250): Nuevo Récord Global -> 0.0000000000
# Iter 666 (Evals 33300): Nuevo Récord Global -> 0.0000000000
# Iter 668 (Evals 33400): Nuevo Récord Global -> 0.0000000000
# Iter 672 (Evals 33600): Nuevo Récord Global -> 0.0000000000
# Iter 676 (Evals 33800): Nuevo Récord Global -> 0.0000000000
# Iter 677 (Evals 33850): Nuevo Récord Global -> 0.0000000000
# Iter 678 (Evals 33900): Nuevo Récord Global -> 0.0000000000
# Iter 679 (Evals 33950): Nuevo Récord Global -> 0.0000000000
# Iter 683 (Evals 34150): Nuevo Récord Global -> 0.0000000000
# Iter 686 (Evals 34300): Nuevo Récord Global -> 0.0000000000
# Iter 687 (Evals 34350): Nuevo Récord Global -> 0.0000000000
# Iter 689 (Evals 34450): Nuevo Récord Global -> 0.0000000000
# Iter 691 (Evals 34550): Nuevo Récord Global -> 0.0000000000
# Iter 694 (Evals 34700): Nuevo Récord Global -> 0.0000000000
# Iter 696 (Evals 34800): Nuevo Récord Global -> 0.0000000000
# Iter 698 (Evals 34900): Nuevo Récord Global -> 0.0000000000
# Iter 700 (Evals 35000): Nuevo Récord Global -> 0.0000000000
# Iter 702 (Evals 35100): Nuevo Récord Global -> 0.0000000000
# Iter 706 (Evals 35300): Nuevo Récord Global -> 0.0000000000
# Iter 707 (Evals 35350): Nuevo Récord Global -> 0.0000000000
# Iter 708 (Evals 35400): Nuevo Récord Global -> 0.0000000000
# Iter 709 (Evals 35450): Nuevo Récord Global -> 0.0000000000
# Iter 710 (Evals 35500): Nuevo Récord Global -> 0.0000000000
# Iter 711 (Evals 35550): Nuevo Récord Global -> 0.0000000000
# Iter 715 (Evals 35750): Nuevo Récord Global -> 0.0000000000
# Iter 716 (Evals 35800): Nuevo Récord Global -> 0.0000000000
# Iter 717 (Evals 35850): Nuevo Récord Global -> 0.0000000000
# Iter 721 (Evals 36050): Nuevo Récord Global -> 0.0000000000
# Iter 723 (Evals 36150): Nuevo Récord Global -> 0.0000000000
# Iter 724 (Evals 36200): Nuevo Récord Global -> 0.0000000000
# Iter 725 (Evals 36250): Nuevo Récord Global -> 0.0000000000
# Iter 727 (Evals 36350): Nuevo Récord Global -> 0.0000000000
# Iter 728 (Evals 36400): Nuevo Récord Global -> 0.0000000000
# Iter 731 (Evals 36550): Nuevo Récord Global -> 0.0000000000
# Iter 734 (Evals 36700): Nuevo Récord Global -> 0.0000000000
# Iter 735 (Evals 36750): Nuevo Récord Global -> 0.0000000000
# Iter 736 (Evals 36800): Nuevo Récord Global -> 0.0000000000
# Iter 737 (Evals 36850): Nuevo Récord Global -> 0.0000000000
# Iter 741 (Evals 37050): Nuevo Récord Global -> 0.0000000000
# Iter 742 (Evals 37100): Nuevo Récord Global -> 0.0000000000
# Iter 743 (Evals 37150): Nuevo Récord Global -> 0.0000000000
# Iter 745 (Evals 37250): Nuevo Récord Global -> 0.0000000000
# Iter 746 (Evals 37300): Nuevo Récord Global -> 0.0000000000
# Iter 747 (Evals 37350): Nuevo Récord Global -> 0.0000000000
# Iter 748 (Evals 37400): Nuevo Récord Global -> 0.0000000000
# Iter 749 (Evals 37450): Nuevo Récord Global -> 0.0000000000
# Iter 750 (Evals 37500): Nuevo Récord Global -> 0.0000000000
# Iter 753 (Evals 37650): Nuevo Récord Global -> 0.0000000000
# Iter 754 (Evals 37700): Nuevo Récord Global -> 0.0000000000
# Iter 758 (Evals 37900): Nuevo Récord Global -> 0.0000000000
# Iter 759 (Evals 37950): Nuevo Récord Global -> 0.0000000000
# Iter 761 (Evals 38050): Nuevo Récord Global -> 0.0000000000
# Iter 764 (Evals 38200): Nuevo Récord Global -> 0.0000000000
# Iter 766 (Evals 38300): Nuevo Récord Global -> 0.0000000000
# Iter 767 (Evals 38350): Nuevo Récord Global -> 0.0000000000
# Iter 768 (Evals 38400): Nuevo Récord Global -> 0.0000000000
# Iter 769 (Evals 38450): Nuevo Récord Global -> 0.0000000000
# Iter 771 (Evals 38550): Nuevo Récord Global -> 0.0000000000
# Iter 775 (Evals 38750): Nuevo Récord Global -> 0.0000000000
# Iter 776 (Evals 38800): Nuevo Récord Global -> 0.0000000000
# Iter 780 (Evals 39000): Nuevo Récord Global -> 0.0000000000
# Iter 782 (Evals 39100): Nuevo Récord Global -> 0.0000000000
# Iter 783 (Evals 39150): Nuevo Récord Global -> 0.0000000000
# Iter 784 (Evals 39200): Nuevo Récord Global -> 0.0000000000
# Iter 787 (Evals 39350): Nuevo Récord Global -> 0.0000000000
# Iter 788 (Evals 39400): Nuevo Récord Global -> 0.0000000000
# Iter 789 (Evals 39450): Nuevo Récord Global -> 0.0000000000
# Iter 793 (Evals 39650): Nuevo Récord Global -> 0.0000000000
# Iter 794 (Evals 39700): Nuevo Récord Global -> 0.0000000000
# Iter 795 (Evals 39750): Nuevo Récord Global -> 0.0000000000
# Iter 798 (Evals 39900): Nuevo Récord Global -> 0.0000000000
# Iter 799 (Evals 39950): Nuevo Récord Global -> 0.0000000000
# Iter 800 (Evals 40000): Nuevo Récord Global -> 0.0000000000
# Iter 801 (Evals 40050): Nuevo Récord Global -> 0.0000000000
# Iter 802 (Evals 40100): Nuevo Récord Global -> 0.0000000000
# Iter 803 (Evals 40150): Nuevo Récord Global -> 0.0000000000
# Iter 806 (Evals 40300): Nuevo Récord Global -> 0.0000000000
# Iter 807 (Evals 40350): Nuevo Récord Global -> 0.0000000000
# Iter 809 (Evals 40450): Nuevo Récord Global -> 0.0000000000
# Iter 810 (Evals 40500): Nuevo Récord Global -> 0.0000000000
# Iter 811 (Evals 40550): Nuevo Récord Global -> 0.0000000000
# Iter 812 (Evals 40600): Nuevo Récord Global -> 0.0000000000
# Iter 814 (Evals 40700): Nuevo Récord Global -> 0.0000000000
# Iter 815 (Evals 40750): Nuevo Récord Global -> 0.0000000000
# Iter 816 (Evals 40800): Nuevo Récord Global -> 0.0000000000
# Iter 818 (Evals 40900): Nuevo Récord Global -> 0.0000000000
# Iter 823 (Evals 41150): Nuevo Récord Global -> 0.0000000000
# Iter 824 (Evals 41200): Nuevo Récord Global -> 0.0000000000
# Iter 826 (Evals 41300): Nuevo Récord Global -> 0.0000000000
# Iter 830 (Evals 41500): Nuevo Récord Global -> 0.0000000000
# Iter 831 (Evals 41550): Nuevo Récord Global -> 0.0000000000
# Iter 835 (Evals 41750): Nuevo Récord Global -> 0.0000000000
# Iter 838 (Evals 41900): Nuevo Récord Global -> 0.0000000000
# Iter 839 (Evals 41950): Nuevo Récord Global -> 0.0000000000
# Iter 840 (Evals 42000): Nuevo Récord Global -> 0.0000000000
# Iter 841 (Evals 42050): Nuevo Récord Global -> 0.0000000000
# Iter 842 (Evals 42100): Nuevo Récord Global -> 0.0000000000
# Iter 843 (Evals 42150): Nuevo Récord Global -> 0.0000000000
# Iter 844 (Evals 42200): Nuevo Récord Global -> 0.0000000000
# Iter 845 (Evals 42250): Nuevo Récord Global -> 0.0000000000
# Iter 846 (Evals 42300): Nuevo Récord Global -> 0.0000000000
# Iter 849 (Evals 42450): Nuevo Récord Global -> 0.0000000000
# Iter 850 (Evals 42500): Nuevo Récord Global -> 0.0000000000
# Iter 851 (Evals 42550): Nuevo Récord Global -> 0.0000000000
# Iter 852 (Evals 42600): Nuevo Récord Global -> 0.0000000000
# Iter 853 (Evals 42650): Nuevo Récord Global -> 0.0000000000
# Iter 855 (Evals 42750): Nuevo Récord Global -> 0.0000000000
# Iter 856 (Evals 42800): Nuevo Récord Global -> 0.0000000000
# Iter 857 (Evals 42850): Nuevo Récord Global -> 0.0000000000
# Iter 858 (Evals 42900): Nuevo Récord Global -> 0.0000000000
# Iter 859 (Evals 42950): Nuevo Récord Global -> 0.0000000000
# Iter 861 (Evals 43050): Nuevo Récord Global -> 0.0000000000
# Iter 862 (Evals 43100): Nuevo Récord Global -> 0.0000000000
# Iter 865 (Evals 43250): Nuevo Récord Global -> 0.0000000000
# Iter 866 (Evals 43300): Nuevo Récord Global -> 0.0000000000
# Iter 869 (Evals 43450): Nuevo Récord Global -> 0.0000000000
# Iter 870 (Evals 43500): Nuevo Récord Global -> 0.0000000000
# Iter 871 (Evals 43550): Nuevo Récord Global -> 0.0000000000
# Iter 873 (Evals 43650): Nuevo Récord Global -> 0.0000000000
# Iter 876 (Evals 43800): Nuevo Récord Global -> 0.0000000000
# Iter 878 (Evals 43900): Nuevo Récord Global -> 0.0000000000
# Iter 882 (Evals 44100): Nuevo Récord Global -> 0.0000000000
# Iter 883 (Evals 44150): Nuevo Récord Global -> 0.0000000000
# Iter 884 (Evals 44200): Nuevo Récord Global -> 0.0000000000
# Iter 886 (Evals 44300): Nuevo Récord Global -> 0.0000000000
# Iter 887 (Evals 44350): Nuevo Récord Global -> 0.0000000000
# Iter 888 (Evals 44400): Nuevo Récord Global -> 0.0000000000
# Iter 893 (Evals 44650): Nuevo Récord Global -> 0.0000000000
# Iter 894 (Evals 44700): Nuevo Récord Global -> 0.0000000000
# Iter 896 (Evals 44800): Nuevo Récord Global -> 0.0000000000
# Iter 897 (Evals 44850): Nuevo Récord Global -> 0.0000000000
# Iter 901 (Evals 45050): Nuevo Récord Global -> 0.0000000000
# Iter 902 (Evals 45100): Nuevo Récord Global -> 0.0000000000
# Iter 903 (Evals 45150): Nuevo Récord Global -> 0.0000000000
# Iter 907 (Evals 45350): Nuevo Récord Global -> 0.0000000000
# Iter 908 (Evals 45400): Nuevo Récord Global -> 0.0000000000
# Iter 909 (Evals 45450): Nuevo Récord Global -> 0.0000000000
# Iter 913 (Evals 45650): Nuevo Récord Global -> 0.0000000000
# Iter 914 (Evals 45700): Nuevo Récord Global -> 0.0000000000
# Iter 916 (Evals 45800): Nuevo Récord Global -> 0.0000000000
# Iter 917 (Evals 45850): Nuevo Récord Global -> 0.0000000000
# Iter 924 (Evals 46200): Nuevo Récord Global -> 0.0000000000
# Iter 925 (Evals 46250): Nuevo Récord Global -> 0.0000000000
# Iter 928 (Evals 46400): Nuevo Récord Global -> 0.0000000000
# Iter 929 (Evals 46450): Nuevo Récord Global -> 0.0000000000
# Iter 932 (Evals 46600): Nuevo Récord Global -> 0.0000000000
# Iter 933 (Evals 46650): Nuevo Récord Global -> 0.0000000000
# Iter 935 (Evals 46750): Nuevo Récord Global -> 0.0000000000
# Iter 938 (Evals 46900): Nuevo Récord Global -> 0.0000000000
# Iter 940 (Evals 47000): Nuevo Récord Global -> 0.0000000000
# Iter 941 (Evals 47050): Nuevo Récord Global -> 0.0000000000
# Iter 945 (Evals 47250): Nuevo Récord Global -> 0.0000000000
# Iter 950 (Evals 47500): Nuevo Récord Global -> 0.0000000000
# Iter 951 (Evals 47550): Nuevo Récord Global -> 0.0000000000
# Iter 952 (Evals 47600): Nuevo Récord Global -> 0.0000000000
# Iter 954 (Evals 47700): Nuevo Récord Global -> 0.0000000000
# Iter 955 (Evals 47750): Nuevo Récord Global -> 0.0000000000
# Iter 958 (Evals 47900): Nuevo Récord Global -> 0.0000000000
# Iter 959 (Evals 47950): Nuevo Récord Global -> 0.0000000000
# Iter 964 (Evals 48200): Nuevo Récord Global -> 0.0000000000
# Iter 966 (Evals 48300): Nuevo Récord Global -> 0.0000000000
# Iter 968 (Evals 48400): Nuevo Récord Global -> 0.0000000000
# Iter 970 (Evals 48500): Nuevo Récord Global -> 0.0000000000
# Iter 973 (Evals 48650): Nuevo Récord Global -> 0.0000000000
# Iter 974 (Evals 48700): Nuevo Récord Global -> 0.0000000000
# Iter 977 (Evals 48850): Nuevo Récord Global -> 0.0000000000
# Iter 981 (Evals 49050): Nuevo Récord Global -> 0.0000000000
# Iter 983 (Evals 49150): Nuevo Récord Global -> 0.0000000000
# Iter 984 (Evals 49200): Nuevo Récord Global -> 0.0000000000
# Iter 985 (Evals 49250): Nuevo Récord Global -> 0.0000000000
# Iter 989 (Evals 49450): Nuevo Récord Global -> 0.0000000000
# Iter 990 (Evals 49500): Nuevo Récord Global -> 0.0000000000
# Iter 991 (Evals 49550): Nuevo Récord Global -> 0.0000000000
# Iter 992 (Evals 49600): Nuevo Récord Global -> 0.0000000000
# Iter 993 (Evals 49650): Nuevo Récord Global -> 0.0000000000
# Iter 994 (Evals 49700): Nuevo Récord Global -> 0.0000000000
# Iter 995 (Evals 49750): Nuevo Récord Global -> 0.0000000000
# Iter 996 (Evals 49800): Nuevo Récord Global -> 0.0000000000
# Iter 997 (Evals 49850): Nuevo Récord Global -> 0.0000000000
# Iter 998 (Evals 49900): Nuevo Récord Global -> 0.0000000000
# Iter 999 (Evals 49950): Nuevo Récord Global -> 0.0000000000
# Iter 1000 (Evals 50000): Nuevo Récord Global -> 0.0000000000
# Iter 1001 (Evals 50050): Nuevo Récord Global -> 0.0000000000
# Iter 1002 (Evals 50100): Nuevo Récord Global -> 0.0000000000
# Iter 1003 (Evals 50150): Nuevo Récord Global -> 0.0000000000
# Iter 1005 (Evals 50250): Nuevo Récord Global -> 0.0000000000
# Iter 1010 (Evals 50500): Nuevo Récord Global -> 0.0000000000
# Iter 1016 (Evals 50800): Nuevo Récord Global -> 0.0000000000
# Iter 1017 (Evals 50850): Nuevo Récord Global -> 0.0000000000
# Iter 1018 (Evals 50900): Nuevo Récord Global -> 0.0000000000
# Iter 1019 (Evals 50950): Nuevo Récord Global -> 0.0000000000
# Iter 1021 (Evals 51050): Nuevo Récord Global -> 0.0000000000
# Iter 1022 (Evals 51100): Nuevo Récord Global -> 0.0000000000
# Iter 1023 (Evals 51150): Nuevo Récord Global -> 0.0000000000
# Iter 1024 (Evals 51200): Nuevo Récord Global -> 0.0000000000
# Iter 1026 (Evals 51300): Nuevo Récord Global -> 0.0000000000
# Iter 1027 (Evals 51350): Nuevo Récord Global -> 0.0000000000
# Iter 1028 (Evals 51400): Nuevo Récord Global -> 0.0000000000
# Iter 1029 (Evals 51450): Nuevo Récord Global -> 0.0000000000
# Iter 1030 (Evals 51500): Nuevo Récord Global -> 0.0000000000
# Iter 1031 (Evals 51550): Nuevo Récord Global -> 0.0000000000
# Iter 1033 (Evals 51650): Nuevo Récord Global -> 0.0000000000
# Iter 1034 (Evals 51700): Nuevo Récord Global -> 0.0000000000
# Iter 1035 (Evals 51750): Nuevo Récord Global -> 0.0000000000
# Iter 1037 (Evals 51850): Nuevo Récord Global -> 0.0000000000
# Iter 1039 (Evals 51950): Nuevo Récord Global -> 0.0000000000
# Iter 1040 (Evals 52000): Nuevo Récord Global -> 0.0000000000
# Iter 1043 (Evals 52150): Nuevo Récord Global -> 0.0000000000
# Iter 1044 (Evals 52200): Nuevo Récord Global -> 0.0000000000
# Iter 1048 (Evals 52400): Nuevo Récord Global -> 0.0000000000
# Iter 1049 (Evals 52450): Nuevo Récord Global -> 0.0000000000
# Iter 1050 (Evals 52500): Nuevo Récord Global -> 0.0000000000
# Iter 1052 (Evals 52600): Nuevo Récord Global -> 0.0000000000
# Iter 1054 (Evals 52700): Nuevo Récord Global -> 0.0000000000
# Iter 1055 (Evals 52750): Nuevo Récord Global -> 0.0000000000
# Iter 1056 (Evals 52800): Nuevo Récord Global -> 0.0000000000
# Iter 1061 (Evals 53050): Nuevo Récord Global -> 0.0000000000
# Iter 1064 (Evals 53200): Nuevo Récord Global -> 0.0000000000
# Iter 1065 (Evals 53250): Nuevo Récord Global -> 0.0000000000
# Iter 1066 (Evals 53300): Nuevo Récord Global -> 0.0000000000
# Iter 1067 (Evals 53350): Nuevo Récord Global -> 0.0000000000
# Iter 1070 (Evals 53500): Nuevo Récord Global -> 0.0000000000
# Iter 1074 (Evals 53700): Nuevo Récord Global -> 0.0000000000
# Iter 1075 (Evals 53750): Nuevo Récord Global -> 0.0000000000
# Iter 1078 (Evals 53900): Nuevo Récord Global -> 0.0000000000
# Iter 1079 (Evals 53950): Nuevo Récord Global -> 0.0000000000
# Iter 1084 (Evals 54200): Nuevo Récord Global -> 0.0000000000
# Iter 1085 (Evals 54250): Nuevo Récord Global -> 0.0000000000
# Iter 1086 (Evals 54300): Nuevo Récord Global -> 0.0000000000
# Iter 1089 (Evals 54450): Nuevo Récord Global -> 0.0000000000
# Iter 1090 (Evals 54500): Nuevo Récord Global -> 0.0000000000
# Iter 1091 (Evals 54550): Nuevo Récord Global -> 0.0000000000
# Iter 1093 (Evals 54650): Nuevo Récord Global -> 0.0000000000
# Iter 1095 (Evals 54750): Nuevo Récord Global -> 0.0000000000
# Iter 1096 (Evals 54800): Nuevo Récord Global -> 0.0000000000
# Iter 1099 (Evals 54950): Nuevo Récord Global -> 0.0000000000
# Iter 1100 (Evals 55000): Nuevo Récord Global -> 0.0000000000
# Iter 1102 (Evals 55100): Nuevo Récord Global -> 0.0000000000
# Iter 1103 (Evals 55150): Nuevo Récord Global -> 0.0000000000
# Iter 1106 (Evals 55300): Nuevo Récord Global -> 0.0000000000
# Iter 1107 (Evals 55350): Nuevo Récord Global -> 0.0000000000
# Iter 1109 (Evals 55450): Nuevo Récord Global -> 0.0000000000
# Iter 1110 (Evals 55500): Nuevo Récord Global -> 0.0000000000
# Iter 1111 (Evals 55550): Nuevo Récord Global -> 0.0000000000
# Iter 1114 (Evals 55700): Nuevo Récord Global -> 0.0000000000
# Iter 1120 (Evals 56000): Nuevo Récord Global -> 0.0000000000
# Iter 1121 (Evals 56050): Nuevo Récord Global -> 0.0000000000
# Iter 1123 (Evals 56150): Nuevo Récord Global -> 0.0000000000
# Iter 1124 (Evals 56200): Nuevo Récord Global -> 0.0000000000
# Iter 1125 (Evals 56250): Nuevo Récord Global -> 0.0000000000
# Iter 1128 (Evals 56400): Nuevo Récord Global -> 0.0000000000
# Iter 1130 (Evals 56500): Nuevo Récord Global -> 0.0000000000
# Iter 1131 (Evals 56550): Nuevo Récord Global -> 0.0000000000
# Iter 1133 (Evals 56650): Nuevo Récord Global -> 0.0000000000
# Iter 1135 (Evals 56750): Nuevo Récord Global -> 0.0000000000
# Iter 1136 (Evals 56800): Nuevo Récord Global -> 0.0000000000
# Iter 1139 (Evals 56950): Nuevo Récord Global -> 0.0000000000
# Iter 1141 (Evals 57050): Nuevo Récord Global -> 0.0000000000
# Iter 1143 (Evals 57150): Nuevo Récord Global -> 0.0000000000
# Iter 1145 (Evals 57250): Nuevo Récord Global -> 0.0000000000
# Iter 1147 (Evals 57350): Nuevo Récord Global -> 0.0000000000
# Iter 1148 (Evals 57400): Nuevo Récord Global -> 0.0000000000
# Iter 1153 (Evals 57650): Nuevo Récord Global -> 0.0000000000
# Iter 1154 (Evals 57700): Nuevo Récord Global -> 0.0000000000
# Iter 1155 (Evals 57750): Nuevo Récord Global -> 0.0000000000
# Iter 1157 (Evals 57850): Nuevo Récord Global -> 0.0000000000
# Iter 1158 (Evals 57900): Nuevo Récord Global -> 0.0000000000
# Iter 1159 (Evals 57950): Nuevo Récord Global -> 0.0000000000
# Iter 1161 (Evals 58050): Nuevo Récord Global -> 0.0000000000
# Iter 1163 (Evals 58150): Nuevo Récord Global -> 0.0000000000
# Iter 1164 (Evals 58200): Nuevo Récord Global -> 0.0000000000
# Iter 1165 (Evals 58250): Nuevo Récord Global -> 0.0000000000
# Iter 1166 (Evals 58300): Nuevo Récord Global -> 0.0000000000
# Iter 1167 (Evals 58350): Nuevo Récord Global -> 0.0000000000
# Iter 1168 (Evals 58400): Nuevo Récord Global -> 0.0000000000
# Iter 1173 (Evals 58650): Nuevo Récord Global -> 0.0000000000
# Iter 1175 (Evals 58750): Nuevo Récord Global -> 0.0000000000
# Iter 1176 (Evals 58800): Nuevo Récord Global -> 0.0000000000
# Iter 1177 (Evals 58850): Nuevo Récord Global -> 0.0000000000
# Iter 1182 (Evals 59100): Nuevo Récord Global -> 0.0000000000
# Iter 1184 (Evals 59200): Nuevo Récord Global -> 0.0000000000
# Iter 1187 (Evals 59350): Nuevo Récord Global -> 0.0000000000
# Iter 1188 (Evals 59400): Nuevo Récord Global -> 0.0000000000
# Iter 1189 (Evals 59450): Nuevo Récord Global -> 0.0000000000
# Iter 1190 (Evals 59500): Nuevo Récord Global -> 0.0000000000
# Iter 1193 (Evals 59650): Nuevo Récord Global -> 0.0000000000
# Iter 1197 (Evals 59850): Nuevo Récord Global -> 0.0000000000
# Iter 1198 (Evals 59900): Nuevo Récord Global -> 0.0000000000
# Iter 1201 (Evals 60050): Nuevo Récord Global -> 0.0000000000
# Iter 1204 (Evals 60200): Nuevo Récord Global -> 0.0000000000
# Iter 1205 (Evals 60250): Nuevo Récord Global -> 0.0000000000
# Iter 1210 (Evals 60500): Nuevo Récord Global -> 0.0000000000
# Iter 1211 (Evals 60550): Nuevo Récord Global -> 0.0000000000
# Iter 1213 (Evals 60650): Nuevo Récord Global -> 0.0000000000
# Iter 1216 (Evals 60800): Nuevo Récord Global -> 0.0000000000
# Iter 1220 (Evals 61000): Nuevo Récord Global -> 0.0000000000
# Iter 1221 (Evals 61050): Nuevo Récord Global -> 0.0000000000
# Iter 1225 (Evals 61250): Nuevo Récord Global -> 0.0000000000
# Iter 1226 (Evals 61300): Nuevo Récord Global -> 0.0000000000
# Iter 1230 (Evals 61500): Nuevo Récord Global -> 0.0000000000
# Iter 1231 (Evals 61550): Nuevo Récord Global -> 0.0000000000
# Iter 1232 (Evals 61600): Nuevo Récord Global -> 0.0000000000
# Iter 1237 (Evals 61850): Nuevo Récord Global -> 0.0000000000
# Iter 1238 (Evals 61900): Nuevo Récord Global -> 0.0000000000
# Iter 1239 (Evals 61950): Nuevo Récord Global -> 0.0000000000
# Iter 1240 (Evals 62000): Nuevo Récord Global -> 0.0000000000
# Iter 1242 (Evals 62100): Nuevo Récord Global -> 0.0000000000
# Iter 1248 (Evals 62400): Nuevo Récord Global -> 0.0000000000
# Iter 1249 (Evals 62450): Nuevo Récord Global -> 0.0000000000
# Iter 1250 (Evals 62500): Nuevo Récord Global -> 0.0000000000
# Iter 1253 (Evals 62650): Nuevo Récord Global -> 0.0000000000
# Iter 1254 (Evals 62700): Nuevo Récord Global -> 0.0000000000
# Iter 1257 (Evals 62850): Nuevo Récord Global -> 0.0000000000
# Iter 1258 (Evals 62900): Nuevo Récord Global -> 0.0000000000
# Iter 1260 (Evals 63000): Nuevo Récord Global -> 0.0000000000
# Iter 1264 (Evals 63200): Nuevo Récord Global -> 0.0000000000
# Iter 1265 (Evals 63250): Nuevo Récord Global -> 0.0000000000
# Iter 1266 (Evals 63300): Nuevo Récord Global -> 0.0000000000
# Iter 1271 (Evals 63550): Nuevo Récord Global -> 0.0000000000
# Iter 1276 (Evals 63800): Nuevo Récord Global -> 0.0000000000
# Iter 1277 (Evals 63850): Nuevo Récord Global -> 0.0000000000
# Iter 1279 (Evals 63950): Nuevo Récord Global -> 0.0000000000
# Iter 1283 (Evals 64150): Nuevo Récord Global -> 0.0000000000
# Iter 1284 (Evals 64200): Nuevo Récord Global -> 0.0000000000
# Iter 1285 (Evals 64250): Nuevo Récord Global -> 0.0000000000
# Iter 1288 (Evals 64400): Nuevo Récord Global -> 0.0000000000
# Iter 1289 (Evals 64450): Nuevo Récord Global -> 0.0000000000
# Iter 1290 (Evals 64500): Nuevo Récord Global -> 0.0000000000
# Iter 1292 (Evals 64600): Nuevo Récord Global -> 0.0000000000
# Iter 1293 (Evals 64650): Nuevo Récord Global -> 0.0000000000
# Iter 1294 (Evals 64700): Nuevo Récord Global -> 0.0000000000
# Iter 1295 (Evals 64750): Nuevo Récord Global -> 0.0000000000
# Iter 1296 (Evals 64800): Nuevo Récord Global -> 0.0000000000
# Iter 1297 (Evals 64850): Nuevo Récord Global -> 0.0000000000
# Iter 1300 (Evals 65000): Nuevo Récord Global -> 0.0000000000
# Iter 1301 (Evals 65050): Nuevo Récord Global -> 0.0000000000
# Iter 1302 (Evals 65100): Nuevo Récord Global -> 0.0000000000
# Iter 1303 (Evals 65150): Nuevo Récord Global -> 0.0000000000
# Iter 1307 (Evals 65350): Nuevo Récord Global -> 0.0000000000
# Iter 1308 (Evals 65400): Nuevo Récord Global -> 0.0000000000
# Iter 1309 (Evals 65450): Nuevo Récord Global -> 0.0000000000
# Iter 1310 (Evals 65500): Nuevo Récord Global -> 0.0000000000
# Iter 1311 (Evals 65550): Nuevo Récord Global -> 0.0000000000
# Iter 1314 (Evals 65700): Nuevo Récord Global -> 0.0000000000
# Iter 1316 (Evals 65800): Nuevo Récord Global -> 0.0000000000
# Iter 1318 (Evals 65900): Nuevo Récord Global -> 0.0000000000
# Iter 1319 (Evals 65950): Nuevo Récord Global -> 0.0000000000
# Iter 1321 (Evals 66050): Nuevo Récord Global -> 0.0000000000
# Iter 1322 (Evals 66100): Nuevo Récord Global -> 0.0000000000
# Iter 1323 (Evals 66150): Nuevo Récord Global -> 0.0000000000
# Iter 1324 (Evals 66200): Nuevo Récord Global -> 0.0000000000
# Iter 1327 (Evals 66350): Nuevo Récord Global -> 0.0000000000
# Iter 1329 (Evals 66450): Nuevo Récord Global -> 0.0000000000
# Iter 1331 (Evals 66550): Nuevo Récord Global -> 0.0000000000
# Iter 1333 (Evals 66650): Nuevo Récord Global -> 0.0000000000
# Iter 1335 (Evals 66750): Nuevo Récord Global -> 0.0000000000
# Iter 1339 (Evals 66950): Nuevo Récord Global -> 0.0000000000
# Iter 1340 (Evals 67000): Nuevo Récord Global -> 0.0000000000
# Iter 1341 (Evals 67050): Nuevo Récord Global -> 0.0000000000
# Iter 1343 (Evals 67150): Nuevo Récord Global -> 0.0000000000
# Iter 1345 (Evals 67250): Nuevo Récord Global -> 0.0000000000
# Iter 1346 (Evals 67300): Nuevo Récord Global -> 0.0000000000
# Iter 1348 (Evals 67400): Nuevo Récord Global -> 0.0000000000
# Iter 1350 (Evals 67500): Nuevo Récord Global -> 0.0000000000
# Iter 1351 (Evals 67550): Nuevo Récord Global -> 0.0000000000
# Iter 1353 (Evals 67650): Nuevo Récord Global -> 0.0000000000
# Iter 1357 (Evals 67850): Nuevo Récord Global -> 0.0000000000
# Iter 1358 (Evals 67900): Nuevo Récord Global -> 0.0000000000
# Iter 1359 (Evals 67950): Nuevo Récord Global -> 0.0000000000
# Iter 1360 (Evals 68000): Nuevo Récord Global -> 0.0000000000
# Iter 1361 (Evals 68050): Nuevo Récord Global -> 0.0000000000
# Iter 1365 (Evals 68250): Nuevo Récord Global -> 0.0000000000
# Iter 1367 (Evals 68350): Nuevo Récord Global -> 0.0000000000
# Iter 1368 (Evals 68400): Nuevo Récord Global -> 0.0000000000
# Iter 1371 (Evals 68550): Nuevo Récord Global -> 0.0000000000
# Iter 1372 (Evals 68600): Nuevo Récord Global -> 0.0000000000
# Iter 1373 (Evals 68650): Nuevo Récord Global -> 0.0000000000
# Iter 1374 (Evals 68700): Nuevo Récord Global -> 0.0000000000
# Iter 1376 (Evals 68800): Nuevo Récord Global -> 0.0000000000
# Iter 1378 (Evals 68900): Nuevo Récord Global -> 0.0000000000
# Iter 1379 (Evals 68950): Nuevo Récord Global -> 0.0000000000
# Iter 1381 (Evals 69050): Nuevo Récord Global -> 0.0000000000
# Iter 1382 (Evals 69100): Nuevo Récord Global -> 0.0000000000
# Iter 1385 (Evals 69250): Nuevo Récord Global -> 0.0000000000
# Iter 1386 (Evals 69300): Nuevo Récord Global -> 0.0000000000
# Iter 1388 (Evals 69400): Nuevo Récord Global -> 0.0000000000
# Iter 1393 (Evals 69650): Nuevo Récord Global -> 0.0000000000
# Iter 1395 (Evals 69750): Nuevo Récord Global -> 0.0000000000
# Iter 1397 (Evals 69850): Nuevo Récord Global -> 0.0000000000
# Iter 1398 (Evals 69900): Nuevo Récord Global -> 0.0000000000
# Iter 1399 (Evals 69950): Nuevo Récord Global -> 0.0000000000
# Iter 1400 (Evals 70000): Nuevo Récord Global -> 0.0000000000
# Iter 1403 (Evals 70150): Nuevo Récord Global -> 0.0000000000
# Iter 1404 (Evals 70200): Nuevo Récord Global -> 0.0000000000
# Iter 1408 (Evals 70400): Nuevo Récord Global -> 0.0000000000
# Iter 1410 (Evals 70500): Nuevo Récord Global -> 0.0000000000
# Iter 1411 (Evals 70550): Nuevo Récord Global -> 0.0000000000
# Iter 1412 (Evals 70600): Nuevo Récord Global -> 0.0000000000
# Iter 1413 (Evals 70650): Nuevo Récord Global -> 0.0000000000
# Iter 1416 (Evals 70800): Nuevo Récord Global -> 0.0000000000
# Iter 1417 (Evals 70850): Nuevo Récord Global -> 0.0000000000
# Iter 1418 (Evals 70900): Nuevo Récord Global -> 0.0000000000
# Iter 1420 (Evals 71000): Nuevo Récord Global -> 0.0000000000
# Iter 1421 (Evals 71050): Nuevo Récord Global -> 0.0000000000
# Iter 1422 (Evals 71100): Nuevo Récord Global -> 0.0000000000
# Iter 1423 (Evals 71150): Nuevo Récord Global -> 0.0000000000
# Iter 1424 (Evals 71200): Nuevo Récord Global -> 0.0000000000
# Iter 1425 (Evals 71250): Nuevo Récord Global -> 0.0000000000
# Iter 1426 (Evals 71300): Nuevo Récord Global -> 0.0000000000
# Iter 1428 (Evals 71400): Nuevo Récord Global -> 0.0000000000
# Iter 1430 (Evals 71500): Nuevo Récord Global -> 0.0000000000
# Iter 1434 (Evals 71700): Nuevo Récord Global -> 0.0000000000
# Iter 1437 (Evals 71850): Nuevo Récord Global -> 0.0000000000
# Iter 1438 (Evals 71900): Nuevo Récord Global -> 0.0000000000
# Iter 1440 (Evals 72000): Nuevo Récord Global -> 0.0000000000
# Iter 1444 (Evals 72200): Nuevo Récord Global -> 0.0000000000
# Iter 1445 (Evals 72250): Nuevo Récord Global -> 0.0000000000
# Iter 1446 (Evals 72300): Nuevo Récord Global -> 0.0000000000
# Iter 1448 (Evals 72400): Nuevo Récord Global -> 0.0000000000
# Iter 1452 (Evals 72600): Nuevo Récord Global -> 0.0000000000
# Iter 1453 (Evals 72650): Nuevo Récord Global -> 0.0000000000
# Iter 1454 (Evals 72700): Nuevo Récord Global -> 0.0000000000
# Iter 1456 (Evals 72800): Nuevo Récord Global -> 0.0000000000
# Iter 1457 (Evals 72850): Nuevo Récord Global -> 0.0000000000
# Iter 1459 (Evals 72950): Nuevo Récord Global -> 0.0000000000
# Iter 1461 (Evals 73050): Nuevo Récord Global -> 0.0000000000
# Iter 1463 (Evals 73150): Nuevo Récord Global -> 0.0000000000
# Iter 1464 (Evals 73200): Nuevo Récord Global -> 0.0000000000
# Iter 1465 (Evals 73250): Nuevo Récord Global -> 0.0000000000
# Iter 1467 (Evals 73350): Nuevo Récord Global -> 0.0000000000
# Iter 1470 (Evals 73500): Nuevo Récord Global -> 0.0000000000
# Iter 1472 (Evals 73600): Nuevo Récord Global -> 0.0000000000
# Iter 1474 (Evals 73700): Nuevo Récord Global -> 0.0000000000
# Iter 1475 (Evals 73750): Nuevo Récord Global -> 0.0000000000
# Iter 1476 (Evals 73800): Nuevo Récord Global -> 0.0000000000
# Iter 1480 (Evals 74000): Nuevo Récord Global -> 0.0000000000
# Iter 1481 (Evals 74050): Nuevo Récord Global -> 0.0000000000
# Iter 1483 (Evals 74150): Nuevo Récord Global -> 0.0000000000
# Iter 1484 (Evals 74200): Nuevo Récord Global -> 0.0000000000
# Iter 1485 (Evals 74250): Nuevo Récord Global -> 0.0000000000
# Iter 1486 (Evals 74300): Nuevo Récord Global -> 0.0000000000
# Iter 1487 (Evals 74350): Nuevo Récord Global -> 0.0000000000
# Iter 1488 (Evals 74400): Nuevo Récord Global -> 0.0000000000
# Iter 1489 (Evals 74450): Nuevo Récord Global -> 0.0000000000
# Iter 1490 (Evals 74500): Nuevo Récord Global -> 0.0000000000
# Iter 1491 (Evals 74550): Nuevo Récord Global -> 0.0000000000
# Iter 1493 (Evals 74650): Nuevo Récord Global -> 0.0000000000
# Iter 1494 (Evals 74700): Nuevo Récord Global -> 0.0000000000
# Iter 1495 (Evals 74750): Nuevo Récord Global -> 0.0000000000
# Iter 1499 (Evals 74950): Nuevo Récord Global -> 0.0000000000
# Iter 1500 (Evals 75000): Nuevo Récord Global -> 0.0000000000
# Iter 1505 (Evals 75250): Nuevo Récord Global -> 0.0000000000
# Iter 1506 (Evals 75300): Nuevo Récord Global -> 0.0000000000
# Iter 1507 (Evals 75350): Nuevo Récord Global -> 0.0000000000
# Iter 1509 (Evals 75450): Nuevo Récord Global -> 0.0000000000
# Iter 1510 (Evals 75500): Nuevo Récord Global -> 0.0000000000
# Iter 1511 (Evals 75550): Nuevo Récord Global -> 0.0000000000
# Iter 1512 (Evals 75600): Nuevo Récord Global -> 0.0000000000
# Iter 1514 (Evals 75700): Nuevo Récord Global -> 0.0000000000
# Iter 1515 (Evals 75750): Nuevo Récord Global -> 0.0000000000
# Iter 1516 (Evals 75800): Nuevo Récord Global -> 0.0000000000
# ...
# Iter 1529 (Evals 76450): Nuevo Récord Global -> 0.0000000000
# Iter 1530 (Evals 76500): Nuevo Récord Global -> 0.0000000000
# Iter 1531 (Evals 76550): Nuevo Récord Global -> 0.0000000000
# Iter 1534 (Evals 76700): Nuevo Récord Global -> 0.0000000000
# Iter 1536 (Evals 76800): Nuevo Récord Global -> 0.0000000000
# Iter 1539 (Evals 76950): Nuevo Récord Global -> 0.0000000000
# Iter 1541 (Evals 77050): Nuevo Récord Global -> 0.0000000000
# Iter 1542 (Evals 77100): Nuevo Récord Global -> 0.0000000000
# Iter 1549 (Evals 77450): Nuevo Récord Global -> 0.0000000000
# Iter 1550 (Evals 77500): Nuevo Récord Global -> 0.0000000000
# Iter 1551 (Evals 77550): Nuevo Récord Global -> 0.0000000000
# Iter 1552 (Evals 77600): Nuevo Récord Global -> 0.0000000000
# Iter 1554 (Evals 77700): Nuevo Récord Global -> 0.0000000000
# Iter 1555 (Evals 77750): Nuevo Récord Global -> 0.0000000000
# Iter 1556 (Evals 77800): Nuevo Récord Global -> 0.0000000000
# Iter 1557 (Evals 77850): Nuevo Récord Global -> 0.0000000000
# Iter 1559 (Evals 77950): Nuevo Récord Global -> 0.0000000000
# Iter 1561 (Evals 78050): Nuevo Récord Global -> 0.0000000000
# Iter 1564 (Evals 78200): Nuevo Récord Global -> 0.0000000000
# Iter 1565 (Evals 78250): Nuevo Récord Global -> 0.0000000000
# Iter 1567 (Evals 78350): Nuevo Récord Global -> 0.0000000000
# Iter 1569 (Evals 78450): Nuevo Récord Global -> 0.0000000000
# Iter 1570 (Evals 78500): Nuevo Récord Global -> 0.0000000000
# Iter 1572 (Evals 78600): Nuevo Récord Global -> 0.0000000000
# Iter 1573 (Evals 78650): Nuevo Récord Global -> 0.0000000000
# Iter 1576 (Evals 78800): Nuevo Récord Global -> 0.0000000000
# Iter 1577 (Evals 78850): Nuevo Récord Global -> 0.0000000000
# Iter 1578 (Evals 78900): Nuevo Récord Global -> 0.0000000000
# Iter 1579 (Evals 78950): Nuevo Récord Global -> 0.0000000000
# Iter 1581 (Evals 79050): Nuevo Récord Global -> 0.0000000000
# Iter 1582 (Evals 79100): Nuevo Récord Global -> 0.0000000000
# Iter 1584 (Evals 79200): Nuevo Récord Global -> 0.0000000000
# Iter 1588 (Evals 79400): Nuevo Récord Global -> 0.0000000000
# Iter 1589 (Evals 79450): Nuevo Récord Global -> 0.0000000000
# Iter 1591 (Evals 79550): Nuevo Récord Global -> 0.0000000000
# Iter 1592 (Evals 79600): Nuevo Récord Global -> 0.0000000000
# Iter 1593 (Evals 79650): Nuevo Récord Global -> 0.0000000000
# Iter 1594 (Evals 79700): Nuevo Récord Global -> 0.0000000000
# Iter 1598 (Evals 79900): Nuevo Récord Global -> 0.0000000000
# Iter 1600 (Evals 80000): Nuevo Récord Global -> 0.0000000000
# Iter 1602 (Evals 80100): Nuevo Récord Global -> 0.0000000000
# Iter 1604 (Evals 80200): Nuevo Récord Global -> 0.0000000000
# Iter 1606 (Evals 80300): Nuevo Récord Global -> 0.0000000000
# Iter 1609 (Evals 80450): Nuevo Récord Global -> 0.0000000000
# Iter 1610 (Evals 80500): Nuevo Récord Global -> 0.0000000000
# Iter 1611 (Evals 80550): Nuevo Récord Global -> 0.0000000000
# Iter 1612 (Evals 80600): Nuevo Récord Global -> 0.0000000000
# Iter 1613 (Evals 80650): Nuevo Récord Global -> 0.0000000000
# Iter 1614 (Evals 80700): Nuevo Récord Global -> 0.0000000000
# Iter 1615 (Evals 80750): Nuevo Récord Global -> 0.0000000000
# Iter 1617 (Evals 80850): Nuevo Récord Global -> 0.0000000000
# Iter 1619 (Evals 80950): Nuevo Récord Global -> 0.0000000000
# Iter 1620 (Evals 81000): Nuevo Récord Global -> 0.0000000000
# Iter 1622 (Evals 81100): Nuevo Récord Global -> 0.0000000000
# Iter 1625 (Evals 81250): Nuevo Récord Global -> 0.0000000000
# Iter 1627 (Evals 81350): Nuevo Récord Global -> 0.0000000000
# Iter 1629 (Evals 81450): Nuevo Récord Global -> 0.0000000000
# Iter 1631 (Evals 81550): Nuevo Récord Global -> 0.0000000000
# Iter 1632 (Evals 81600): Nuevo Récord Global -> 0.0000000000
# Iter 1633 (Evals 81650): Nuevo Récord Global -> 0.0000000000
# Iter 1635 (Evals 81750): Nuevo Récord Global -> 0.0000000000
# Iter 1636 (Evals 81800): Nuevo Récord Global -> 0.0000000000
# Iter 1637 (Evals 81850): Nuevo Récord Global -> 0.0000000000
# Iter 1640 (Evals 82000): Nuevo Récord Global -> 0.0000000000
# Iter 1644 (Evals 82200): Nuevo Récord Global -> 0.0000000000
# Iter 1649 (Evals 82450): Nuevo Récord Global -> 0.0000000000
# Iter 1650 (Evals 82500): Nuevo Récord Global -> 0.0000000000
# Iter 1652 (Evals 82600): Nuevo Récord Global -> 0.0000000000
# Iter 1653 (Evals 82650): Nuevo Récord Global -> 0.0000000000
# Iter 1656 (Evals 82800): Nuevo Récord Global -> 0.0000000000
# Iter 1657 (Evals 82850): Nuevo Récord Global -> 0.0000000000
# Iter 1659 (Evals 82950): Nuevo Récord Global -> 0.0000000000
# Iter 1661 (Evals 83050): Nuevo Récord Global -> 0.0000000000
# Iter 1662 (Evals 83100): Nuevo Récord Global -> 0.0000000000
# Iter 1663 (Evals 83150): Nuevo Récord Global -> 0.0000000000
# Iter 1666 (Evals 83300): Nuevo Récord Global -> 0.0000000000
# Iter 1669 (Evals 83450): Nuevo Récord Global -> 0.0000000000
# Iter 1670 (Evals 83500): Nuevo Récord Global -> 0.0000000000
# Iter 1671 (Evals 83550): Nuevo Récord Global -> 0.0000000000
# Iter 1676 (Evals 83800): Nuevo Récord Global -> 0.0000000000
# Iter 1680 (Evals 84000): Nuevo Récord Global -> 0.0000000000
# Iter 1682 (Evals 84100): Nuevo Récord Global -> 0.0000000000
# Iter 1687 (Evals 84350): Nuevo Récord Global -> 0.0000000000
# Iter 1689 (Evals 84450): Nuevo Récord Global -> 0.0000000000
# Iter 1690 (Evals 84500): Nuevo Récord Global -> 0.0000000000
# Iter 1692 (Evals 84600): Nuevo Récord Global -> 0.0000000000
# Iter 1696 (Evals 84800): Nuevo Récord Global -> 0.0000000000
# Iter 1697 (Evals 84850): Nuevo Récord Global -> 0.0000000000
# Iter 1699 (Evals 84950): Nuevo Récord Global -> 0.0000000000
# Iter 1702 (Evals 85100): Nuevo Récord Global -> 0.0000000000
# Iter 1705 (Evals 85250): Nuevo Récord Global -> 0.0000000000
# Iter 1706 (Evals 85300): Nuevo Récord Global -> 0.0000000000
# Iter 1707 (Evals 85350): Nuevo Récord Global -> 0.0000000000
# Iter 1709 (Evals 85450): Nuevo Récord Global -> 0.0000000000
# Iter 1711 (Evals 85550): Nuevo Récord Global -> 0.0000000000
# Iter 1712 (Evals 85600): Nuevo Récord Global -> 0.0000000000
# Iter 1721 (Evals 86050): Nuevo Récord Global -> 0.0000000000
# Iter 1722 (Evals 86100): Nuevo Récord Global -> 0.0000000000
# Iter 1723 (Evals 86150): Nuevo Récord Global -> 0.0000000000
# Iter 1724 (Evals 86200): Nuevo Récord Global -> 0.0000000000
# Iter 1725 (Evals 86250): Nuevo Récord Global -> 0.0000000000
# Iter 1726 (Evals 86300): Nuevo Récord Global -> 0.0000000000
# Iter 1728 (Evals 86400): Nuevo Récord Global -> 0.0000000000
# Iter 1730 (Evals 86500): Nuevo Récord Global -> 0.0000000000
# Iter 1731 (Evals 86550): Nuevo Récord Global -> 0.0000000000
# Iter 1733 (Evals 86650): Nuevo Récord Global -> 0.0000000000
# Iter 1734 (Evals 86700): Nuevo Récord Global -> 0.0000000000
# Iter 1735 (Evals 86750): Nuevo Récord Global -> 0.0000000000
# Iter 1736 (Evals 86800): Nuevo Récord Global -> 0.0000000000
# Iter 1737 (Evals 86850): Nuevo Récord Global -> 0.0000000000
# Iter 1739 (Evals 86950): Nuevo Récord Global -> 0.0000000000
# Iter 1740 (Evals 87000): Nuevo Récord Global -> 0.0000000000
# Iter 1741 (Evals 87050): Nuevo Récord Global -> 0.0000000000
# Iter 1742 (Evals 87100): Nuevo Récord Global -> 0.0000000000
# Iter 1743 (Evals 87150): Nuevo Récord Global -> 0.0000000000
# Iter 1746 (Evals 87300): Nuevo Récord Global -> 0.0000000000
# Iter 1747 (Evals 87350): Nuevo Récord Global -> 0.0000000000
# Iter 1748 (Evals 87400): Nuevo Récord Global -> 0.0000000000
# Iter 1750 (Evals 87500): Nuevo Récord Global -> 0.0000000000
# Iter 1751 (Evals 87550): Nuevo Récord Global -> 0.0000000000
# Iter 1752 (Evals 87600): Nuevo Récord Global -> 0.0000000000
# Iter 1753 (Evals 87650): Nuevo Récord Global -> 0.0000000000
# Iter 1754 (Evals 87700): Nuevo Récord Global -> 0.0000000000
# Iter 1756 (Evals 87800): Nuevo Récord Global -> 0.0000000000
# Iter 1758 (Evals 87900): Nuevo Récord Global -> 0.0000000000
# Iter 1763 (Evals 88150): Nuevo Récord Global -> 0.0000000000
# Iter 1764 (Evals 88200): Nuevo Récord Global -> 0.0000000000
# Iter 1765 (Evals 88250): Nuevo Récord Global -> 0.0000000000
# Iter 1766 (Evals 88300): Nuevo Récord Global -> 0.0000000000
# Iter 1769 (Evals 88450): Nuevo Récord Global -> 0.0000000000
# Iter 1770 (Evals 88500): Nuevo Récord Global -> 0.0000000000
# Iter 1771 (Evals 88550): Nuevo Récord Global -> 0.0000000000
# Iter 1774 (Evals 88700): Nuevo Récord Global -> 0.0000000000
# Iter 1776 (Evals 88800): Nuevo Récord Global -> 0.0000000000
# Iter 1777 (Evals 88850): Nuevo Récord Global -> 0.0000000000
# Iter 1781 (Evals 89050): Nuevo Récord Global -> 0.0000000000
# Iter 1782 (Evals 89100): Nuevo Récord Global -> 0.0000000000
# Iter 1784 (Evals 89200): Nuevo Récord Global -> 0.0000000000
# Iter 1786 (Evals 89300): Nuevo Récord Global -> 0.0000000000
# Iter 1788 (Evals 89400): Nuevo Récord Global -> 0.0000000000
# Iter 1789 (Evals 89450): Nuevo Récord Global -> 0.0000000000
# Iter 1791 (Evals 89550): Nuevo Récord Global -> 0.0000000000
# Iter 1792 (Evals 89600): Nuevo Récord Global -> 0.0000000000
# Iter 1794 (Evals 89700): Nuevo Récord Global -> 0.0000000000
# Iter 1798 (Evals 89900): Nuevo Récord Global -> 0.0000000000
# Iter 1800 (Evals 90000): Nuevo Récord Global -> 0.0000000000
# Iter 1802 (Evals 90100): Nuevo Récord Global -> 0.0000000000
# Iter 1805 (Evals 90250): Nuevo Récord Global -> 0.0000000000
# Iter 1806 (Evals 90300): Nuevo Récord Global -> 0.0000000000
# Iter 1807 (Evals 90350): Nuevo Récord Global -> 0.0000000000
# Iter 1808 (Evals 90400): Nuevo Récord Global -> 0.0000000000
# Iter 1809 (Evals 90450): Nuevo Récord Global -> 0.0000000000
# Iter 1811 (Evals 90550): Nuevo Récord Global -> 0.0000000000
# Iter 1815 (Evals 90750): Nuevo Récord Global -> 0.0000000000
# Iter 1816 (Evals 90800): Nuevo Récord Global -> 0.0000000000
# Iter 1817 (Evals 90850): Nuevo Récord Global -> 0.0000000000
# Iter 1818 (Evals 90900): Nuevo Récord Global -> 0.0000000000
# Iter 1819 (Evals 90950): Nuevo Récord Global -> 0.0000000000
# Iter 1820 (Evals 91000): Nuevo Récord Global -> 0.0000000000
# Iter 1822 (Evals 91100): Nuevo Récord Global -> 0.0000000000
# Iter 1823 (Evals 91150): Nuevo Récord Global -> 0.0000000000
# Iter 1824 (Evals 91200): Nuevo Récord Global -> 0.0000000000
# Iter 1828 (Evals 91400): Nuevo Récord Global -> 0.0000000000
# Iter 1829 (Evals 91450): Nuevo Récord Global -> 0.0000000000
# Iter 1832 (Evals 91600): Nuevo Récord Global -> 0.0000000000
# Iter 1833 (Evals 91650): Nuevo Récord Global -> 0.0000000000
# Iter 1834 (Evals 91700): Nuevo Récord Global -> 0.0000000000
# Iter 1836 (Evals 91800): Nuevo Récord Global -> 0.0000000000
# Iter 1837 (Evals 91850): Nuevo Récord Global -> 0.0000000000
# Iter 1838 (Evals 91900): Nuevo Récord Global -> 0.0000000000
# Iter 1839 (Evals 91950): Nuevo Récord Global -> 0.0000000000
# Iter 1840 (Evals 92000): Nuevo Récord Global -> 0.0000000000
# Iter 1842 (Evals 92100): Nuevo Récord Global -> 0.0000000000
# Iter 1843 (Evals 92150): Nuevo Récord Global -> 0.0000000000
# Iter 1845 (Evals 92250): Nuevo Récord Global -> 0.0000000000
# Iter 1846 (Evals 92300): Nuevo Récord Global -> 0.0000000000
# Iter 1851 (Evals 92550): Nuevo Récord Global -> 0.0000000000
# Iter 1855 (Evals 92750): Nuevo Récord Global -> 0.0000000000
# Iter 1857 (Evals 92850): Nuevo Récord Global -> 0.0000000000
# Iter 1858 (Evals 92900): Nuevo Récord Global -> 0.0000000000
# Iter 1861 (Evals 93050): Nuevo Récord Global -> 0.0000000000
# Iter 1862 (Evals 93100): Nuevo Récord Global -> 0.0000000000
# Iter 1863 (Evals 93150): Nuevo Récord Global -> 0.0000000000
# Iter 1865 (Evals 93250): Nuevo Récord Global -> 0.0000000000
# Iter 1866 (Evals 93300): Nuevo Récord Global -> 0.0000000000
# Iter 1867 (Evals 93350): Nuevo Récord Global -> 0.0000000000
# Iter 1868 (Evals 93400): Nuevo Récord Global -> 0.0000000000
# Iter 1869 (Evals 93450): Nuevo Récord Global -> 0.0000000000
# Iter 1871 (Evals 93550): Nuevo Récord Global -> 0.0000000000
# Iter 1874 (Evals 93700): Nuevo Récord Global -> 0.0000000000
# Iter 1875 (Evals 93750): Nuevo Récord Global -> 0.0000000000
# Iter 1876 (Evals 93800): Nuevo Récord Global -> 0.0000000000
# Iter 1877 (Evals 93850): Nuevo Récord Global -> 0.0000000000
# Iter 1878 (Evals 93900): Nuevo Récord Global -> 0.0000000000
# Iter 1880 (Evals 94000): Nuevo Récord Global -> 0.0000000000
# Iter 1882 (Evals 94100): Nuevo Récord Global -> 0.0000000000
# Iter 1883 (Evals 94150): Nuevo Récord Global -> 0.0000000000
# Iter 1884 (Evals 94200): Nuevo Récord Global -> 0.0000000000
# Iter 1885 (Evals 94250): Nuevo Récord Global -> 0.0000000000
# Iter 1886 (Evals 94300): Nuevo Récord Global -> 0.0000000000
# Iter 1887 (Evals 94350): Nuevo Récord Global -> 0.0000000000
# Iter 1889 (Evals 94450): Nuevo Récord Global -> 0.0000000000
# Iter 1893 (Evals 94650): Nuevo Récord Global -> 0.0000000000
# Iter 1894 (Evals 94700): Nuevo Récord Global -> 0.0000000000
# Iter 1895 (Evals 94750): Nuevo Récord Global -> 0.0000000000
# Iter 1896 (Evals 94800): Nuevo Récord Global -> 0.0000000000
# Iter 1901 (Evals 95050): Nuevo Récord Global -> 0.0000000000
# Iter 1905 (Evals 95250): Nuevo Récord Global -> 0.0000000000
# Iter 1906 (Evals 95300): Nuevo Récord Global -> 0.0000000000
# Iter 1908 (Evals 95400): Nuevo Récord Global -> 0.0000000000
# Iter 1909 (Evals 95450): Nuevo Récord Global -> 0.0000000000
# Iter 1910 (Evals 95500): Nuevo Récord Global -> 0.0000000000
# Iter 1911 (Evals 95550): Nuevo Récord Global -> 0.0000000000
# Iter 1913 (Evals 95650): Nuevo Récord Global -> 0.0000000000
# Iter 1914 (Evals 95700): Nuevo Récord Global -> 0.0000000000
# Iter 1915 (Evals 95750): Nuevo Récord Global -> 0.0000000000
# Iter 1917 (Evals 95850): Nuevo Récord Global -> 0.0000000000
# Iter 1918 (Evals 95900): Nuevo Récord Global -> 0.0000000000
# Iter 1920 (Evals 96000): Nuevo Récord Global -> 0.0000000000
# Iter 1923 (Evals 96150): Nuevo Récord Global -> 0.0000000000
# Iter 1926 (Evals 96300): Nuevo Récord Global -> 0.0000000000
# Iter 1927 (Evals 96350): Nuevo Récord Global -> 0.0000000000
# Iter 1928 (Evals 96400): Nuevo Récord Global -> 0.0000000000
# Iter 1932 (Evals 96600): Nuevo Récord Global -> 0.0000000000
# Iter 1933 (Evals 96650): Nuevo Récord Global -> 0.0000000000
# Iter 1936 (Evals 96800): Nuevo Récord Global -> 0.0000000000
# Iter 1939 (Evals 96950): Nuevo Récord Global -> 0.0000000000
# Iter 1940 (Evals 97000): Nuevo Récord Global -> 0.0000000000
# Iter 1941 (Evals 97050): Nuevo Récord Global -> 0.0000000000
# Iter 1944 (Evals 97200): Nuevo Récord Global -> 0.0000000000
# Iter 1945 (Evals 97250): Nuevo Récord Global -> 0.0000000000
# Iter 1946 (Evals 97300): Nuevo Récord Global -> 0.0000000000
# Iter 1950 (Evals 97500): Nuevo Récord Global -> 0.0000000000
# Iter 1951 (Evals 97550): Nuevo Récord Global -> 0.0000000000
# Iter 1952 (Evals 97600): Nuevo Récord Global -> 0.0000000000
# Iter 1954 (Evals 97700): Nuevo Récord Global -> 0.0000000000
# Iter 1955 (Evals 97750): Nuevo Récord Global -> 0.0000000000
# Iter 1956 (Evals 97800): Nuevo Récord Global -> 0.0000000000
# Iter 1960 (Evals 98000): Nuevo Récord Global -> 0.0000000000
# Iter 1961 (Evals 98050): Nuevo Récord Global -> 0.0000000000
# Iter 1964 (Evals 98200): Nuevo Récord Global -> 0.0000000000
# Iter 1974 (Evals 98700): Nuevo Récord Global -> 0.0000000000
# Iter 1975 (Evals 98750): Nuevo Récord Global -> 0.0000000000
# Iter 1977 (Evals 98850): Nuevo Récord Global -> 0.0000000000
# Iter 1978 (Evals 98900): Nuevo Récord Global -> 0.0000000000
# Iter 1979 (Evals 98950): Nuevo Récord Global -> 0.0000000000
# Iter 1980 (Evals 99000): Nuevo Récord Global -> 0.0000000000
# Iter 1981 (Evals 99050): Nuevo Récord Global -> 0.0000000000
# Iter 1982 (Evals 99100): Nuevo Récord Global -> 0.0000000000
# Iter 1984 (Evals 99200): Nuevo Récord Global -> 0.0000000000
# Iter 1985 (Evals 99250): Nuevo Récord Global -> 0.0000000000
# Iter 1986 (Evals 99300): Nuevo Récord Global -> 0.0000000000
# Iter 1987 (Evals 99350): Nuevo Récord Global -> 0.0000000000
# Iter 1989 (Evals 99450): Nuevo Récord Global -> 0.0000000000
# Iter 1992 (Evals 99600): Nuevo Récord Global -> 0.0000000000
# Iter 1993 (Evals 99650): Nuevo Récord Global -> 0.0000000000
# Iter 1994 (Evals 99700): Nuevo Récord Global -> 0.0000000000
# Iter 1995 (Evals 99750): Nuevo Récord Global -> 0.0000000000
# Iter 1996 (Evals 99800): Nuevo Récord Global -> 0.0000000000
# Iter 1997 (Evals 99850): Nuevo Récord Global -> 0.0000000000
# Iter 1998 (Evals 99900): Nuevo Récord Global -> 0.0000000000
#
# Resultado final (debe ser cercano a 0): 1.0817023186468855e-128
