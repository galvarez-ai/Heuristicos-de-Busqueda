# %%
import numpy as np

# %%
class PSO:
    def __init__(self, max_evals=10*5):
        self.posicion_de_cada_elemento = np.random.uniform(-5.12, 5.12, size=(50,10)) #Pos
        self.velocidad_de_cada_elemento = np.random.uniform(0, 10, size=(50,10)) #vel
        self.mejor_fitness_de_cada_elemento = np.zeros((50, 10))
        
        self.gBest = -1
        self.bestFitness = [np.inf] * 10

        self.max_evals=max_evals
        
    def actualizar_posiciones(self):
        formula = 0.7 * self.velocidad_de_cada_elemento[:] + 1.5 * np.random.random() * (self.mejor_fitness_de_cada_elemento[:] 
                    - self.posicion_de_cada_elemento[:]) + 1.5 * np.random.random() * (self.posicion_de_cada_elemento[self.gBest] - self.posicion_de_cada_elemento[:])         
        self.posicion_de_cada_elemento[:] += formula
        self.velocidad_de_cada_elemento = formula

    def get_modularity(self, solution):
        return np.sum(self.posicion_de_cada_elemento[solution]**2)

    def run(self):
        evals = 0
        while evals < self.max_evals:
            evals += 1
            #Actualizamos mejores modularidades y nos quedamos con el mejor
            for i in range(50):
                lag = [self.get_modularity(i)] * 10
                if lag[0] < self.mejor_fitness_de_cada_elemento[i][0]:
                    self.mejor_fitness_de_cada_elemento[i] = lag
                if lag < self.bestFitness:
                    self.gBest = i
                    self.bestFitness = lag
                    print(f"Mejor fitnes actualizado: {self.bestFitness[0]} conseguido por la particula {self.gBest}")

            self.actualizar_posiciones()

# %%
'''
1. Poblacion 50 arrays de 10 elementos
2. For
3. Calculamos modularidad de cada elemento
4. Actualizamos al lider y mejor recuerdo de cada uno
5. Movemos los puntos
6. Repetimos hasta ...
'''
# Out:
# '\n1. Poblacion 50 arrays de 10 elementos\n2. For\n3. Calculamos modularidad de cada elemento\n4. Actualizamos al lider y mejor recuerdo de cada uno\n5. Movemos los puntos\n6. Repetimos hasta ...\n'

# %%
pso = PSO()

# %%
pso.run()
# Out:
# Mejor fitnes actualizado: 76.84392997245669 conseguido por la particula 0
# Mejor fitnes actualizado: 75.79257176120618 conseguido por la particula 1
# Mejor fitnes actualizado: 60.37245650839118 conseguido por la particula 2
# Mejor fitnes actualizado: 36.8511620340254 conseguido por la particula 9
# Mejor fitnes actualizado: 8.909774615409356 conseguido por la particula 9
# Mejor fitnes actualizado: 4.418742815049756 conseguido por la particula 0
# Mejor fitnes actualizado: 3.793958181664269 conseguido por la particula 1
# Mejor fitnes actualizado: 3.0121511647284684 conseguido por la particula 5
# Mejor fitnes actualizado: 2.932826453808683 conseguido por la particula 9
# Mejor fitnes actualizado: 1.1290286694965037 conseguido por la particula 11
# Mejor fitnes actualizado: 0.16373147975186575 conseguido por la particula 11
# Mejor fitnes actualizado: 0.002364505325406198 conseguido por la particula 11
# Mejor fitnes actualizado: 0.001275703472179495 conseguido por la particula 11

# %%
np.random.random()
# Out:
# 0.6810113668643034

# %%
import numpy as np

class PSO_Exam:
    def __init__(self, n_particles=50, n_dim=10, max_evals=100000):
        self.n_particles = n_particles
        self.n_dim = n_dim
        self.max_evals = max_evals
        
        # --- 1. INICIALIZACIÓN ---
        # Rango [-5.12, 5.12]
        self.X = np.random.uniform(-5.12, 5.12, (n_particles, n_dim))
        # Velocidad inicial pequeña (ceros o random pequeño)
        self.V = np.random.randn(n_particles, n_dim) * 0.1
        
        # --- 2. MEMORIA (pBest y gBest) ---
        # Mejor posición personal (pBest): Al principio es la actual
        self.pBest_pos = self.X.copy()
        # Mejor nota personal: Al principio es la actual
        self.pBest_val = np.array([self.get_fitness(ind) for ind in self.X])
        
        # Mejor global (gBest): El mejor de los personales
        best_idx = np.argmin(self.pBest_val)
        self.gBest_pos = self.pBest_pos[best_idx].copy()
        self.gBest_val = self.pBest_val[best_idx]
        
        # Hiperparámetros del enunciado
        self.w = 0.7  # Inercia
        self.c1 = 1.5 # Cognitivo
        self.c2 = 1.5 # Social

    def get_fitness(self, particle):
        """
        Función Sphere: Suma de cuadrados.
        Recibe un array (10,) y devuelve un float.
        """
        return np.sum(particle**2)

    def update_particles(self):
        """
        El Motor Físico: Mueve todo el enjambre a la vez usando matrices.
        """
        # Generamos aleatorios (r1, r2) para TODAS las coordenadas de golpe
        r1 = np.random.rand(self.n_particles, self.n_dim)
        r2 = np.random.rand(self.n_particles, self.n_dim)
        
        # --- FÓRMULA DE VELOCIDAD (Vectorizada) ---
        # v_new = w*v + c1*r1*(pBest - X) + c2*r2*(gBest - X)
        inertia = self.w * self.V
        cognitive = self.c1 * r1 * (self.pBest_pos - self.X)
        social = self.c2 * r2 * (self.gBest_pos - self.X) # Numpy resta vector gBest a cada fila de X
        
        self.V = inertia + cognitive + social
        
        # --- FÓRMULA DE POSICIÓN ---
        self.X = self.X + self.V
        
        # Opcional: Limitar al rango (rebotar o clippear) para no salir del mapa
        self.X = np.clip(self.X, -5.12, 5.12)

    def run(self):
        evals = 0
        iteration = 0
        
        # Como evaluamos 50 partículas por ciclo, avanzamos de 50 en 50
        while evals < self.max_evals:
            iteration += 1
            
            # 1. MOVER ENJAMBRE
            self.update_particles()
            
            # 2. EVALUAR Y ACTUALIZAR MEMORIA
            # Calculamos fitness de las nuevas posiciones
            # (Vectorizado: aplicamos la función a cada fila)
            current_fitness_values = np.array([self.get_fitness(p) for p in self.X])
            evals += self.n_particles
            
            # 3. ACTUALIZAR pBest (Personal)
            # Buscamos dónde hemos mejorado (máscara booleana)
            improved_indices = current_fitness_values < self.pBest_val
            
            # Actualizamos solo donde hubo mejora
            self.pBest_pos[improved_indices] = self.X[improved_indices]
            self.pBest_val[improved_indices] = current_fitness_values[improved_indices]
            
            # 4. ACTUALIZAR gBest (Global)
            # Miramos si alguien de la nueva generación ha superado el récord mundial
            min_val_iter = np.min(self.pBest_val)
            min_idx_iter = np.argmin(self.pBest_val)
            
            if min_val_iter < self.gBest_val:
                self.gBest_val = min_val_iter
                self.gBest_pos = self.pBest_pos[min_idx_iter].copy()
                print(f"Iter {iteration} (Evals {evals}): Nuevo Récord Global -> {self.gBest_val:.10f}")
                
        return self.gBest_val

# --- TEST DEL EXAMEN ---
pso_solver = PSO_Exam()
resultado = pso_solver.run()
print(f"\nResultado final (debe ser cercano a 0): {resultado}")
# Out:
# Iter 1 (Evals 50): Nuevo Récord Global -> 23.0579934781
# Iter 3 (Evals 150): Nuevo Récord Global -> 21.6215230284
# Iter 4 (Evals 200): Nuevo Récord Global -> 20.6035645727
# Iter 6 (Evals 300): Nuevo Récord Global -> 20.3839647267
# Iter 7 (Evals 350): Nuevo Récord Global -> 13.9110888959
# Iter 8 (Evals 400): Nuevo Récord Global -> 6.6695877660
# Iter 9 (Evals 450): Nuevo Récord Global -> 4.6111033805
# Iter 11 (Evals 550): Nuevo Récord Global -> 4.3618832535
# Iter 12 (Evals 600): Nuevo Récord Global -> 3.2414913277
# Iter 14 (Evals 700): Nuevo Récord Global -> 2.5134658738
# Iter 15 (Evals 750): Nuevo Récord Global -> 2.3932447714
# Iter 16 (Evals 800): Nuevo Récord Global -> 2.0838360392
# Iter 17 (Evals 850): Nuevo Récord Global -> 1.6220844370
# Iter 19 (Evals 950): Nuevo Récord Global -> 0.8900618853
# Iter 21 (Evals 1050): Nuevo Récord Global -> 0.8353620200
# Iter 22 (Evals 1100): Nuevo Récord Global -> 0.7865472602
# Iter 25 (Evals 1250): Nuevo Récord Global -> 0.6788046213
# Iter 26 (Evals 1300): Nuevo Récord Global -> 0.3947309642
# Iter 28 (Evals 1400): Nuevo Récord Global -> 0.2582677532
# Iter 29 (Evals 1450): Nuevo Récord Global -> 0.2009145373
# Iter 33 (Evals 1650): Nuevo Récord Global -> 0.1191106199
# Iter 34 (Evals 1700): Nuevo Récord Global -> 0.0774103601
# Iter 37 (Evals 1850): Nuevo Récord Global -> 0.0608172530
# Iter 40 (Evals 2000): Nuevo Récord Global -> 0.0427714570
# Iter 44 (Evals 2200): Nuevo Récord Global -> 0.0379293677
# Iter 45 (Evals 2250): Nuevo Récord Global -> 0.0326359928
# Iter 49 (Evals 2450): Nuevo Récord Global -> 0.0259494797
# Iter 50 (Evals 2500): Nuevo Récord Global -> 0.0249390520
# Iter 51 (Evals 2550): Nuevo Récord Global -> 0.0217195420
# Iter 52 (Evals 2600): Nuevo Récord Global -> 0.0080210782
# Iter 55 (Evals 2750): Nuevo Récord Global -> 0.0045716685
# Iter 58 (Evals 2900): Nuevo Récord Global -> 0.0041494764
# Iter 61 (Evals 3050): Nuevo Récord Global -> 0.0026470449
# Iter 63 (Evals 3150): Nuevo Récord Global -> 0.0022443130
# Iter 66 (Evals 3300): Nuevo Récord Global -> 0.0016586663
# Iter 67 (Evals 3350): Nuevo Récord Global -> 0.0011629495
# Iter 69 (Evals 3450): Nuevo Récord Global -> 0.0010355994
# Iter 70 (Evals 3500): Nuevo Récord Global -> 0.0007219005
# Iter 72 (Evals 3600): Nuevo Récord Global -> 0.0005686697
# Iter 74 (Evals 3700): Nuevo Récord Global -> 0.0004285572
# Iter 76 (Evals 3800): Nuevo Récord Global -> 0.0003060690
# Iter 79 (Evals 3950): Nuevo Récord Global -> 0.0003025396
# Iter 80 (Evals 4000): Nuevo Récord Global -> 0.0002012504
# Iter 81 (Evals 4050): Nuevo Récord Global -> 0.0001495464
# Iter 84 (Evals 4200): Nuevo Récord Global -> 0.0001292289
# Iter 86 (Evals 4300): Nuevo Récord Global -> 0.0000976381
# Iter 88 (Evals 4400): Nuevo Récord Global -> 0.0000962213
# Iter 90 (Evals 4500): Nuevo Récord Global -> 0.0000547950
# Iter 93 (Evals 4650): Nuevo Récord Global -> 0.0000462549
# Iter 94 (Evals 4700): Nuevo Récord Global -> 0.0000308108
# Iter 95 (Evals 4750): Nuevo Récord Global -> 0.0000247640
# Iter 96 (Evals 4800): Nuevo Récord Global -> 0.0000200935
# Iter 98 (Evals 4900): Nuevo Récord Global -> 0.0000197999
# Iter 99 (Evals 4950): Nuevo Récord Global -> 0.0000124580
# Iter 100 (Evals 5000): Nuevo Récord Global -> 0.0000093990
# Iter 101 (Evals 5050): Nuevo Récord Global -> 0.0000073654
# Iter 105 (Evals 5250): Nuevo Récord Global -> 0.0000024333
# Iter 109 (Evals 5450): Nuevo Récord Global -> 0.0000020990
# Iter 110 (Evals 5500): Nuevo Récord Global -> 0.0000018976
# Iter 111 (Evals 5550): Nuevo Récord Global -> 0.0000007943
# Iter 112 (Evals 5600): Nuevo Récord Global -> 0.0000004370
# Iter 114 (Evals 5700): Nuevo Récord Global -> 0.0000004136
# Iter 116 (Evals 5800): Nuevo Récord Global -> 0.0000003415
# Iter 117 (Evals 5850): Nuevo Récord Global -> 0.0000002417
# Iter 119 (Evals 5950): Nuevo Récord Global -> 0.0000001271
# Iter 123 (Evals 6150): Nuevo Récord Global -> 0.0000000700
# Iter 125 (Evals 6250): Nuevo Récord Global -> 0.0000000642
# Iter 127 (Evals 6350): Nuevo Récord Global -> 0.0000000555
# Iter 129 (Evals 6450): Nuevo Récord Global -> 0.0000000293
# Iter 131 (Evals 6550): Nuevo Récord Global -> 0.0000000252
# Iter 132 (Evals 6600): Nuevo Récord Global -> 0.0000000139
# Iter 133 (Evals 6650): Nuevo Récord Global -> 0.0000000131
# Iter 134 (Evals 6700): Nuevo Récord Global -> 0.0000000110
# Iter 136 (Evals 6800): Nuevo Récord Global -> 0.0000000075
# Iter 140 (Evals 7000): Nuevo Récord Global -> 0.0000000069
# Iter 144 (Evals 7200): Nuevo Récord Global -> 0.0000000034
# Iter 147 (Evals 7350): Nuevo Récord Global -> 0.0000000030
# Iter 149 (Evals 7450): Nuevo Récord Global -> 0.0000000015
# Iter 152 (Evals 7600): Nuevo Récord Global -> 0.0000000013
# Iter 153 (Evals 7650): Nuevo Récord Global -> 0.0000000009
# Iter 154 (Evals 7700): Nuevo Récord Global -> 0.0000000007
# Iter 155 (Evals 7750): Nuevo Récord Global -> 0.0000000006
# Iter 156 (Evals 7800): Nuevo Récord Global -> 0.0000000004
# Iter 159 (Evals 7950): Nuevo Récord Global -> 0.0000000003
# Iter 162 (Evals 8100): Nuevo Récord Global -> 0.0000000002
# Iter 163 (Evals 8150): Nuevo Récord Global -> 0.0000000002
# Iter 166 (Evals 8300): Nuevo Récord Global -> 0.0000000002
# Iter 167 (Evals 8350): Nuevo Récord Global -> 0.0000000002
# Iter 168 (Evals 8400): Nuevo Récord Global -> 0.0000000001
# Iter 170 (Evals 8500): Nuevo Récord Global -> 0.0000000001
# Iter 171 (Evals 8550): Nuevo Récord Global -> 0.0000000001
# Iter 172 (Evals 8600): Nuevo Récord Global -> 0.0000000001
# Iter 174 (Evals 8700): Nuevo Récord Global -> 0.0000000000
# Iter 177 (Evals 8850): Nuevo Récord Global -> 0.0000000000
# Iter 179 (Evals 8950): Nuevo Récord Global -> 0.0000000000
# Iter 180 (Evals 9000): Nuevo Récord Global -> 0.0000000000
# Iter 181 (Evals 9050): Nuevo Récord Global -> 0.0000000000
# Iter 183 (Evals 9150): Nuevo Récord Global -> 0.0000000000
# Iter 184 (Evals 9200): Nuevo Récord Global -> 0.0000000000
# Iter 185 (Evals 9250): Nuevo Récord Global -> 0.0000000000
# Iter 186 (Evals 9300): Nuevo Récord Global -> 0.0000000000
# Iter 191 (Evals 9550): Nuevo Récord Global -> 0.0000000000
# Iter 193 (Evals 9650): Nuevo Récord Global -> 0.0000000000
# Iter 194 (Evals 9700): Nuevo Récord Global -> 0.0000000000
# Iter 195 (Evals 9750): Nuevo Récord Global -> 0.0000000000
# Iter 196 (Evals 9800): Nuevo Récord Global -> 0.0000000000
# Iter 197 (Evals 9850): Nuevo Récord Global -> 0.0000000000
# Iter 198 (Evals 9900): Nuevo Récord Global -> 0.0000000000
# Iter 202 (Evals 10100): Nuevo Récord Global -> 0.0000000000
# Iter 203 (Evals 10150): Nuevo Récord Global -> 0.0000000000
# Iter 207 (Evals 10350): Nuevo Récord Global -> 0.0000000000
# Iter 210 (Evals 10500): Nuevo Récord Global -> 0.0000000000
# Iter 211 (Evals 10550): Nuevo Récord Global -> 0.0000000000
# Iter 212 (Evals 10600): Nuevo Récord Global -> 0.0000000000
# Iter 213 (Evals 10650): Nuevo Récord Global -> 0.0000000000
# Iter 214 (Evals 10700): Nuevo Récord Global -> 0.0000000000
# Iter 215 (Evals 10750): Nuevo Récord Global -> 0.0000000000
# Iter 216 (Evals 10800): Nuevo Récord Global -> 0.0000000000
# Iter 217 (Evals 10850): Nuevo Récord Global -> 0.0000000000
# Iter 218 (Evals 10900): Nuevo Récord Global -> 0.0000000000
# Iter 226 (Evals 11300): Nuevo Récord Global -> 0.0000000000
# Iter 227 (Evals 11350): Nuevo Récord Global -> 0.0000000000
# Iter 228 (Evals 11400): Nuevo Récord Global -> 0.0000000000
# Iter 231 (Evals 11550): Nuevo Récord Global -> 0.0000000000
# Iter 232 (Evals 11600): Nuevo Récord Global -> 0.0000000000
# Iter 234 (Evals 11700): Nuevo Récord Global -> 0.0000000000
# Iter 235 (Evals 11750): Nuevo Récord Global -> 0.0000000000
# Iter 236 (Evals 11800): Nuevo Récord Global -> 0.0000000000
# Iter 237 (Evals 11850): Nuevo Récord Global -> 0.0000000000
# Iter 238 (Evals 11900): Nuevo Récord Global -> 0.0000000000
# Iter 244 (Evals 12200): Nuevo Récord Global -> 0.0000000000
# Iter 247 (Evals 12350): Nuevo Récord Global -> 0.0000000000
# Iter 248 (Evals 12400): Nuevo Récord Global -> 0.0000000000
# Iter 249 (Evals 12450): Nuevo Récord Global -> 0.0000000000
# Iter 253 (Evals 12650): Nuevo Récord Global -> 0.0000000000
# Iter 255 (Evals 12750): Nuevo Récord Global -> 0.0000000000
# Iter 256 (Evals 12800): Nuevo Récord Global -> 0.0000000000
# Iter 257 (Evals 12850): Nuevo Récord Global -> 0.0000000000
# Iter 258 (Evals 12900): Nuevo Récord Global -> 0.0000000000
# Iter 261 (Evals 13050): Nuevo Récord Global -> 0.0000000000
# Iter 262 (Evals 13100): Nuevo Récord Global -> 0.0000000000
# Iter 265 (Evals 13250): Nuevo Récord Global -> 0.0000000000
# Iter 268 (Evals 13400): Nuevo Récord Global -> 0.0000000000
# Iter 269 (Evals 13450): Nuevo Récord Global -> 0.0000000000
# Iter 270 (Evals 13500): Nuevo Récord Global -> 0.0000000000
# Iter 271 (Evals 13550): Nuevo Récord Global -> 0.0000000000
# Iter 274 (Evals 13700): Nuevo Récord Global -> 0.0000000000
# Iter 276 (Evals 13800): Nuevo Récord Global -> 0.0000000000
# Iter 277 (Evals 13850): Nuevo Récord Global -> 0.0000000000
# Iter 279 (Evals 13950): Nuevo Récord Global -> 0.0000000000
# Iter 280 (Evals 14000): Nuevo Récord Global -> 0.0000000000
# Iter 281 (Evals 14050): Nuevo Récord Global -> 0.0000000000
# Iter 282 (Evals 14100): Nuevo Récord Global -> 0.0000000000
# Iter 283 (Evals 14150): Nuevo Récord Global -> 0.0000000000
# Iter 284 (Evals 14200): Nuevo Récord Global -> 0.0000000000
# Iter 285 (Evals 14250): Nuevo Récord Global -> 0.0000000000
# Iter 288 (Evals 14400): Nuevo Récord Global -> 0.0000000000
# Iter 289 (Evals 14450): Nuevo Récord Global -> 0.0000000000
# Iter 290 (Evals 14500): Nuevo Récord Global -> 0.0000000000
# Iter 292 (Evals 14600): Nuevo Récord Global -> 0.0000000000
# Iter 293 (Evals 14650): Nuevo Récord Global -> 0.0000000000
# Iter 295 (Evals 14750): Nuevo Récord Global -> 0.0000000000
# Iter 299 (Evals 14950): Nuevo Récord Global -> 0.0000000000
# Iter 302 (Evals 15100): Nuevo Récord Global -> 0.0000000000
# Iter 304 (Evals 15200): Nuevo Récord Global -> 0.0000000000
# Iter 306 (Evals 15300): Nuevo Récord Global -> 0.0000000000
# Iter 307 (Evals 15350): Nuevo Récord Global -> 0.0000000000
# Iter 308 (Evals 15400): Nuevo Récord Global -> 0.0000000000
# Iter 309 (Evals 15450): Nuevo Récord Global -> 0.0000000000
# Iter 310 (Evals 15500): Nuevo Récord Global -> 0.0000000000
# Iter 313 (Evals 15650): Nuevo Récord Global -> 0.0000000000
# Iter 315 (Evals 15750): Nuevo Récord Global -> 0.0000000000
# Iter 316 (Evals 15800): Nuevo Récord Global -> 0.0000000000
# Iter 317 (Evals 15850): Nuevo Récord Global -> 0.0000000000
# Iter 319 (Evals 15950): Nuevo Récord Global -> 0.0000000000
# Iter 321 (Evals 16050): Nuevo Récord Global -> 0.0000000000
# Iter 326 (Evals 16300): Nuevo Récord Global -> 0.0000000000
# Iter 327 (Evals 16350): Nuevo Récord Global -> 0.0000000000
# Iter 329 (Evals 16450): Nuevo Récord Global -> 0.0000000000
# Iter 330 (Evals 16500): Nuevo Récord Global -> 0.0000000000
# Iter 332 (Evals 16600): Nuevo Récord Global -> 0.0000000000
# Iter 334 (Evals 16700): Nuevo Récord Global -> 0.0000000000
# Iter 336 (Evals 16800): Nuevo Récord Global -> 0.0000000000
# Iter 338 (Evals 16900): Nuevo Récord Global -> 0.0000000000
# Iter 339 (Evals 16950): Nuevo Récord Global -> 0.0000000000
# Iter 341 (Evals 17050): Nuevo Récord Global -> 0.0000000000
# Iter 344 (Evals 17200): Nuevo Récord Global -> 0.0000000000
# Iter 346 (Evals 17300): Nuevo Récord Global -> 0.0000000000
# Iter 347 (Evals 17350): Nuevo Récord Global -> 0.0000000000
# Iter 352 (Evals 17600): Nuevo Récord Global -> 0.0000000000
# Iter 353 (Evals 17650): Nuevo Récord Global -> 0.0000000000
# Iter 355 (Evals 17750): Nuevo Récord Global -> 0.0000000000
# Iter 357 (Evals 17850): Nuevo Récord Global -> 0.0000000000
# Iter 359 (Evals 17950): Nuevo Récord Global -> 0.0000000000
# Iter 360 (Evals 18000): Nuevo Récord Global -> 0.0000000000
# Iter 362 (Evals 18100): Nuevo Récord Global -> 0.0000000000
# Iter 363 (Evals 18150): Nuevo Récord Global -> 0.0000000000
# Iter 364 (Evals 18200): Nuevo Récord Global -> 0.0000000000
# Iter 366 (Evals 18300): Nuevo Récord Global -> 0.0000000000
# Iter 367 (Evals 18350): Nuevo Récord Global -> 0.0000000000
# Iter 368 (Evals 18400): Nuevo Récord Global -> 0.0000000000
# Iter 369 (Evals 18450): Nuevo Récord Global -> 0.0000000000
# Iter 371 (Evals 18550): Nuevo Récord Global -> 0.0000000000
# Iter 372 (Evals 18600): Nuevo Récord Global -> 0.0000000000
# Iter 374 (Evals 18700): Nuevo Récord Global -> 0.0000000000
# Iter 379 (Evals 18950): Nuevo Récord Global -> 0.0000000000
# Iter 380 (Evals 19000): Nuevo Récord Global -> 0.0000000000
# Iter 382 (Evals 19100): Nuevo Récord Global -> 0.0000000000
# Iter 383 (Evals 19150): Nuevo Récord Global -> 0.0000000000
# Iter 385 (Evals 19250): Nuevo Récord Global -> 0.0000000000
# Iter 387 (Evals 19350): Nuevo Récord Global -> 0.0000000000
# Iter 389 (Evals 19450): Nuevo Récord Global -> 0.0000000000
# Iter 392 (Evals 19600): Nuevo Récord Global -> 0.0000000000
# Iter 395 (Evals 19750): Nuevo Récord Global -> 0.0000000000
# Iter 397 (Evals 19850): Nuevo Récord Global -> 0.0000000000
# Iter 399 (Evals 19950): Nuevo Récord Global -> 0.0000000000
# Iter 400 (Evals 20000): Nuevo Récord Global -> 0.0000000000
# Iter 402 (Evals 20100): Nuevo Récord Global -> 0.0000000000
# Iter 403 (Evals 20150): Nuevo Récord Global -> 0.0000000000
# Iter 405 (Evals 20250): Nuevo Récord Global -> 0.0000000000
# Iter 407 (Evals 20350): Nuevo Récord Global -> 0.0000000000
# Iter 408 (Evals 20400): Nuevo Récord Global -> 0.0000000000
# Iter 409 (Evals 20450): Nuevo Récord Global -> 0.0000000000
# Iter 410 (Evals 20500): Nuevo Récord Global -> 0.0000000000
# Iter 412 (Evals 20600): Nuevo Récord Global -> 0.0000000000
# Iter 413 (Evals 20650): Nuevo Récord Global -> 0.0000000000
# Iter 416 (Evals 20800): Nuevo Récord Global -> 0.0000000000
# Iter 418 (Evals 20900): Nuevo Récord Global -> 0.0000000000
# Iter 419 (Evals 20950): Nuevo Récord Global -> 0.0000000000
# Iter 420 (Evals 21000): Nuevo Récord Global -> 0.0000000000
# Iter 422 (Evals 21100): Nuevo Récord Global -> 0.0000000000
# Iter 423 (Evals 21150): Nuevo Récord Global -> 0.0000000000
# Iter 426 (Evals 21300): Nuevo Récord Global -> 0.0000000000
# Iter 430 (Evals 21500): Nuevo Récord Global -> 0.0000000000
# Iter 431 (Evals 21550): Nuevo Récord Global -> 0.0000000000
# Iter 432 (Evals 21600): Nuevo Récord Global -> 0.0000000000
# Iter 436 (Evals 21800): Nuevo Récord Global -> 0.0000000000
# Iter 437 (Evals 21850): Nuevo Récord Global -> 0.0000000000
# Iter 438 (Evals 21900): Nuevo Récord Global -> 0.0000000000
# Iter 439 (Evals 21950): Nuevo Récord Global -> 0.0000000000
# Iter 442 (Evals 22100): Nuevo Récord Global -> 0.0000000000
# Iter 443 (Evals 22150): Nuevo Récord Global -> 0.0000000000
# Iter 445 (Evals 22250): Nuevo Récord Global -> 0.0000000000
# Iter 447 (Evals 22350): Nuevo Récord Global -> 0.0000000000
# Iter 449 (Evals 22450): Nuevo Récord Global -> 0.0000000000
# Iter 450 (Evals 22500): Nuevo Récord Global -> 0.0000000000
# Iter 452 (Evals 22600): Nuevo Récord Global -> 0.0000000000
# Iter 454 (Evals 22700): Nuevo Récord Global -> 0.0000000000
# Iter 455 (Evals 22750): Nuevo Récord Global -> 0.0000000000
# Iter 456 (Evals 22800): Nuevo Récord Global -> 0.0000000000
# Iter 457 (Evals 22850): Nuevo Récord Global -> 0.0000000000
# Iter 460 (Evals 23000): Nuevo Récord Global -> 0.0000000000
# Iter 461 (Evals 23050): Nuevo Récord Global -> 0.0000000000
# Iter 464 (Evals 23200): Nuevo Récord Global -> 0.0000000000
# Iter 465 (Evals 23250): Nuevo Récord Global -> 0.0000000000
# Iter 466 (Evals 23300): Nuevo Récord Global -> 0.0000000000
# Iter 469 (Evals 23450): Nuevo Récord Global -> 0.0000000000
# Iter 471 (Evals 23550): Nuevo Récord Global -> 0.0000000000
# Iter 473 (Evals 23650): Nuevo Récord Global -> 0.0000000000
# Iter 474 (Evals 23700): Nuevo Récord Global -> 0.0000000000
# Iter 475 (Evals 23750): Nuevo Récord Global -> 0.0000000000
# Iter 478 (Evals 23900): Nuevo Récord Global -> 0.0000000000
# Iter 479 (Evals 23950): Nuevo Récord Global -> 0.0000000000
# Iter 481 (Evals 24050): Nuevo Récord Global -> 0.0000000000
# Iter 482 (Evals 24100): Nuevo Récord Global -> 0.0000000000
# Iter 483 (Evals 24150): Nuevo Récord Global -> 0.0000000000
# Iter 489 (Evals 24450): Nuevo Récord Global -> 0.0000000000
# Iter 490 (Evals 24500): Nuevo Récord Global -> 0.0000000000
# Iter 492 (Evals 24600): Nuevo Récord Global -> 0.0000000000
# Iter 495 (Evals 24750): Nuevo Récord Global -> 0.0000000000
# Iter 496 (Evals 24800): Nuevo Récord Global -> 0.0000000000
# Iter 498 (Evals 24900): Nuevo Récord Global -> 0.0000000000
# Iter 499 (Evals 24950): Nuevo Récord Global -> 0.0000000000
# Iter 500 (Evals 25000): Nuevo Récord Global -> 0.0000000000
# Iter 501 (Evals 25050): Nuevo Récord Global -> 0.0000000000
# Iter 502 (Evals 25100): Nuevo Récord Global -> 0.0000000000
# Iter 503 (Evals 25150): Nuevo Récord Global -> 0.0000000000
# Iter 504 (Evals 25200): Nuevo Récord Global -> 0.0000000000
# Iter 506 (Evals 25300): Nuevo Récord Global -> 0.0000000000
# Iter 507 (Evals 25350): Nuevo Récord Global -> 0.0000000000
# Iter 509 (Evals 25450): Nuevo Récord Global -> 0.0000000000
# Iter 510 (Evals 25500): Nuevo Récord Global -> 0.0000000000
# Iter 513 (Evals 25650): Nuevo Récord Global -> 0.0000000000
# Iter 515 (Evals 25750): Nuevo Récord Global -> 0.0000000000
# Iter 516 (Evals 25800): Nuevo Récord Global -> 0.0000000000
# Iter 518 (Evals 25900): Nuevo Récord Global -> 0.0000000000
# Iter 523 (Evals 26150): Nuevo Récord Global -> 0.0000000000
# Iter 526 (Evals 26300): Nuevo Récord Global -> 0.0000000000
# Iter 527 (Evals 26350): Nuevo Récord Global -> 0.0000000000
# Iter 531 (Evals 26550): Nuevo Récord Global -> 0.0000000000
# Iter 532 (Evals 26600): Nuevo Récord Global -> 0.0000000000
# Iter 533 (Evals 26650): Nuevo Récord Global -> 0.0000000000
# Iter 534 (Evals 26700): Nuevo Récord Global -> 0.0000000000
# Iter 535 (Evals 26750): Nuevo Récord Global -> 0.0000000000
# Iter 536 (Evals 26800): Nuevo Récord Global -> 0.0000000000
# Iter 538 (Evals 26900): Nuevo Récord Global -> 0.0000000000
# Iter 539 (Evals 26950): Nuevo Récord Global -> 0.0000000000
# Iter 540 (Evals 27000): Nuevo Récord Global -> 0.0000000000
# Iter 542 (Evals 27100): Nuevo Récord Global -> 0.0000000000
# Iter 545 (Evals 27250): Nuevo Récord Global -> 0.0000000000
# Iter 546 (Evals 27300): Nuevo Récord Global -> 0.0000000000
# Iter 547 (Evals 27350): Nuevo Récord Global -> 0.0000000000
# Iter 548 (Evals 27400): Nuevo Récord Global -> 0.0000000000
# Iter 549 (Evals 27450): Nuevo Récord Global -> 0.0000000000
# Iter 550 (Evals 27500): Nuevo Récord Global -> 0.0000000000
# Iter 553 (Evals 27650): Nuevo Récord Global -> 0.0000000000
# Iter 555 (Evals 27750): Nuevo Récord Global -> 0.0000000000
# Iter 556 (Evals 27800): Nuevo Récord Global -> 0.0000000000
# Iter 558 (Evals 27900): Nuevo Récord Global -> 0.0000000000
# Iter 561 (Evals 28050): Nuevo Récord Global -> 0.0000000000
# Iter 562 (Evals 28100): Nuevo Récord Global -> 0.0000000000
# Iter 563 (Evals 28150): Nuevo Récord Global -> 0.0000000000
# Iter 564 (Evals 28200): Nuevo Récord Global -> 0.0000000000
# Iter 566 (Evals 28300): Nuevo Récord Global -> 0.0000000000
# Iter 567 (Evals 28350): Nuevo Récord Global -> 0.0000000000
# Iter 569 (Evals 28450): Nuevo Récord Global -> 0.0000000000
# Iter 571 (Evals 28550): Nuevo Récord Global -> 0.0000000000
# Iter 575 (Evals 28750): Nuevo Récord Global -> 0.0000000000
# Iter 576 (Evals 28800): Nuevo Récord Global -> 0.0000000000
# Iter 582 (Evals 29100): Nuevo Récord Global -> 0.0000000000
# Iter 584 (Evals 29200): Nuevo Récord Global -> 0.0000000000
# Iter 587 (Evals 29350): Nuevo Récord Global -> 0.0000000000
# Iter 588 (Evals 29400): Nuevo Récord Global -> 0.0000000000
# Iter 589 (Evals 29450): Nuevo Récord Global -> 0.0000000000
# Iter 590 (Evals 29500): Nuevo Récord Global -> 0.0000000000
# Iter 593 (Evals 29650): Nuevo Récord Global -> 0.0000000000
# Iter 594 (Evals 29700): Nuevo Récord Global -> 0.0000000000
# Iter 595 (Evals 29750): Nuevo Récord Global -> 0.0000000000
# Iter 597 (Evals 29850): Nuevo Récord Global -> 0.0000000000
# Iter 598 (Evals 29900): Nuevo Récord Global -> 0.0000000000
# Iter 599 (Evals 29950): Nuevo Récord Global -> 0.0000000000
# Iter 600 (Evals 30000): Nuevo Récord Global -> 0.0000000000
# Iter 603 (Evals 30150): Nuevo Récord Global -> 0.0000000000
# Iter 604 (Evals 30200): Nuevo Récord Global -> 0.0000000000
# Iter 608 (Evals 30400): Nuevo Récord Global -> 0.0000000000
# Iter 609 (Evals 30450): Nuevo Récord Global -> 0.0000000000
# Iter 610 (Evals 30500): Nuevo Récord Global -> 0.0000000000
# Iter 612 (Evals 30600): Nuevo Récord Global -> 0.0000000000
# Iter 615 (Evals 30750): Nuevo Récord Global -> 0.0000000000
# Iter 617 (Evals 30850): Nuevo Récord Global -> 0.0000000000
# Iter 618 (Evals 30900): Nuevo Récord Global -> 0.0000000000
# Iter 623 (Evals 31150): Nuevo Récord Global -> 0.0000000000
# Iter 625 (Evals 31250): Nuevo Récord Global -> 0.0000000000
# Iter 627 (Evals 31350): Nuevo Récord Global -> 0.0000000000
# Iter 628 (Evals 31400): Nuevo Récord Global -> 0.0000000000
# Iter 629 (Evals 31450): Nuevo Récord Global -> 0.0000000000
# Iter 630 (Evals 31500): Nuevo Récord Global -> 0.0000000000
# Iter 631 (Evals 31550): Nuevo Récord Global -> 0.0000000000
# Iter 632 (Evals 31600): Nuevo Récord Global -> 0.0000000000
# Iter 633 (Evals 31650): Nuevo Récord Global -> 0.0000000000
# Iter 635 (Evals 31750): Nuevo Récord Global -> 0.0000000000
# Iter 636 (Evals 31800): Nuevo Récord Global -> 0.0000000000
# Iter 638 (Evals 31900): Nuevo Récord Global -> 0.0000000000
# Iter 641 (Evals 32050): Nuevo Récord Global -> 0.0000000000
# Iter 643 (Evals 32150): Nuevo Récord Global -> 0.0000000000
# Iter 646 (Evals 32300): Nuevo Récord Global -> 0.0000000000
# Iter 648 (Evals 32400): Nuevo Récord Global -> 0.0000000000
# Iter 650 (Evals 32500): Nuevo Récord Global -> 0.0000000000
# Iter 651 (Evals 32550): Nuevo Récord Global -> 0.0000000000
# Iter 653 (Evals 32650): Nuevo Récord Global -> 0.0000000000
# Iter 656 (Evals 32800): Nuevo Récord Global -> 0.0000000000
# Iter 657 (Evals 32850): Nuevo Récord Global -> 0.0000000000
# Iter 658 (Evals 32900): Nuevo Récord Global -> 0.0000000000
# Iter 660 (Evals 33000): Nuevo Récord Global -> 0.0000000000
# Iter 661 (Evals 33050): Nuevo Récord Global -> 0.0000000000
# Iter 662 (Evals 33100): Nuevo Récord Global -> 0.0000000000
# Iter 663 (Evals 33150): Nuevo Récord Global -> 0.0000000000
# Iter 664 (Evals 33200): Nuevo Récord Global -> 0.0000000000
# Iter 667 (Evals 33350): Nuevo Récord Global -> 0.0000000000
# Iter 668 (Evals 33400): Nuevo Récord Global -> 0.0000000000
# Iter 670 (Evals 33500): Nuevo Récord Global -> 0.0000000000
# Iter 671 (Evals 33550): Nuevo Récord Global -> 0.0000000000
# Iter 672 (Evals 33600): Nuevo Récord Global -> 0.0000000000
# Iter 673 (Evals 33650): Nuevo Récord Global -> 0.0000000000
# Iter 677 (Evals 33850): Nuevo Récord Global -> 0.0000000000
# Iter 679 (Evals 33950): Nuevo Récord Global -> 0.0000000000
# Iter 680 (Evals 34000): Nuevo Récord Global -> 0.0000000000
# Iter 682 (Evals 34100): Nuevo Récord Global -> 0.0000000000
# Iter 683 (Evals 34150): Nuevo Récord Global -> 0.0000000000
# Iter 684 (Evals 34200): Nuevo Récord Global -> 0.0000000000
# Iter 685 (Evals 34250): Nuevo Récord Global -> 0.0000000000
# Iter 687 (Evals 34350): Nuevo Récord Global -> 0.0000000000
# Iter 688 (Evals 34400): Nuevo Récord Global -> 0.0000000000
# Iter 689 (Evals 34450): Nuevo Récord Global -> 0.0000000000
# Iter 692 (Evals 34600): Nuevo Récord Global -> 0.0000000000
# Iter 693 (Evals 34650): Nuevo Récord Global -> 0.0000000000
# Iter 695 (Evals 34750): Nuevo Récord Global -> 0.0000000000
# Iter 698 (Evals 34900): Nuevo Récord Global -> 0.0000000000
# Iter 699 (Evals 34950): Nuevo Récord Global -> 0.0000000000
# Iter 701 (Evals 35050): Nuevo Récord Global -> 0.0000000000
# Iter 704 (Evals 35200): Nuevo Récord Global -> 0.0000000000
# Iter 705 (Evals 35250): Nuevo Récord Global -> 0.0000000000
# Iter 707 (Evals 35350): Nuevo Récord Global -> 0.0000000000
# Iter 711 (Evals 35550): Nuevo Récord Global -> 0.0000000000
# Iter 712 (Evals 35600): Nuevo Récord Global -> 0.0000000000
# Iter 716 (Evals 35800): Nuevo Récord Global -> 0.0000000000
# Iter 718 (Evals 35900): Nuevo Récord Global -> 0.0000000000
# Iter 723 (Evals 36150): Nuevo Récord Global -> 0.0000000000
# Iter 724 (Evals 36200): Nuevo Récord Global -> 0.0000000000
# Iter 725 (Evals 36250): Nuevo Récord Global -> 0.0000000000
# Iter 729 (Evals 36450): Nuevo Récord Global -> 0.0000000000
# Iter 730 (Evals 36500): Nuevo Récord Global -> 0.0000000000
# Iter 731 (Evals 36550): Nuevo Récord Global -> 0.0000000000
# Iter 732 (Evals 36600): Nuevo Récord Global -> 0.0000000000
# Iter 734 (Evals 36700): Nuevo Récord Global -> 0.0000000000
# Iter 735 (Evals 36750): Nuevo Récord Global -> 0.0000000000
# Iter 736 (Evals 36800): Nuevo Récord Global -> 0.0000000000
# Iter 737 (Evals 36850): Nuevo Récord Global -> 0.0000000000
# Iter 739 (Evals 36950): Nuevo Récord Global -> 0.0000000000
# Iter 742 (Evals 37100): Nuevo Récord Global -> 0.0000000000
# Iter 743 (Evals 37150): Nuevo Récord Global -> 0.0000000000
# Iter 744 (Evals 37200): Nuevo Récord Global -> 0.0000000000
# Iter 748 (Evals 37400): Nuevo Récord Global -> 0.0000000000
# Iter 750 (Evals 37500): Nuevo Récord Global -> 0.0000000000
# Iter 751 (Evals 37550): Nuevo Récord Global -> 0.0000000000
# Iter 752 (Evals 37600): Nuevo Récord Global -> 0.0000000000
# Iter 753 (Evals 37650): Nuevo Récord Global -> 0.0000000000
# Iter 754 (Evals 37700): Nuevo Récord Global -> 0.0000000000
# Iter 756 (Evals 37800): Nuevo Récord Global -> 0.0000000000
# Iter 758 (Evals 37900): Nuevo Récord Global -> 0.0000000000
# Iter 760 (Evals 38000): Nuevo Récord Global -> 0.0000000000
# Iter 763 (Evals 38150): Nuevo Récord Global -> 0.0000000000
# Iter 764 (Evals 38200): Nuevo Récord Global -> 0.0000000000
# Iter 766 (Evals 38300): Nuevo Récord Global -> 0.0000000000
# Iter 767 (Evals 38350): Nuevo Récord Global -> 0.0000000000
# Iter 768 (Evals 38400): Nuevo Récord Global -> 0.0000000000
# Iter 770 (Evals 38500): Nuevo Récord Global -> 0.0000000000
# Iter 771 (Evals 38550): Nuevo Récord Global -> 0.0000000000
# Iter 774 (Evals 38700): Nuevo Récord Global -> 0.0000000000
# Iter 775 (Evals 38750): Nuevo Récord Global -> 0.0000000000
# Iter 777 (Evals 38850): Nuevo Récord Global -> 0.0000000000
# Iter 778 (Evals 38900): Nuevo Récord Global -> 0.0000000000
# Iter 779 (Evals 38950): Nuevo Récord Global -> 0.0000000000
# Iter 781 (Evals 39050): Nuevo Récord Global -> 0.0000000000
# Iter 785 (Evals 39250): Nuevo Récord Global -> 0.0000000000
# Iter 788 (Evals 39400): Nuevo Récord Global -> 0.0000000000
# Iter 789 (Evals 39450): Nuevo Récord Global -> 0.0000000000
# Iter 791 (Evals 39550): Nuevo Récord Global -> 0.0000000000
# Iter 792 (Evals 39600): Nuevo Récord Global -> 0.0000000000
# Iter 795 (Evals 39750): Nuevo Récord Global -> 0.0000000000
# Iter 797 (Evals 39850): Nuevo Récord Global -> 0.0000000000
# Iter 798 (Evals 39900): Nuevo Récord Global -> 0.0000000000
# Iter 801 (Evals 40050): Nuevo Récord Global -> 0.0000000000
# Iter 802 (Evals 40100): Nuevo Récord Global -> 0.0000000000
# Iter 803 (Evals 40150): Nuevo Récord Global -> 0.0000000000
# Iter 804 (Evals 40200): Nuevo Récord Global -> 0.0000000000
# Iter 809 (Evals 40450): Nuevo Récord Global -> 0.0000000000
# Iter 812 (Evals 40600): Nuevo Récord Global -> 0.0000000000
# Iter 813 (Evals 40650): Nuevo Récord Global -> 0.0000000000
# Iter 814 (Evals 40700): Nuevo Récord Global -> 0.0000000000
# Iter 817 (Evals 40850): Nuevo Récord Global -> 0.0000000000
# Iter 821 (Evals 41050): Nuevo Récord Global -> 0.0000000000
# Iter 822 (Evals 41100): Nuevo Récord Global -> 0.0000000000
# Iter 823 (Evals 41150): Nuevo Récord Global -> 0.0000000000
# Iter 824 (Evals 41200): Nuevo Récord Global -> 0.0000000000
# Iter 825 (Evals 41250): Nuevo Récord Global -> 0.0000000000
# Iter 829 (Evals 41450): Nuevo Récord Global -> 0.0000000000
# Iter 831 (Evals 41550): Nuevo Récord Global -> 0.0000000000
# Iter 832 (Evals 41600): Nuevo Récord Global -> 0.0000000000
# Iter 833 (Evals 41650): Nuevo Récord Global -> 0.0000000000
# Iter 834 (Evals 41700): Nuevo Récord Global -> 0.0000000000
# Iter 837 (Evals 41850): Nuevo Récord Global -> 0.0000000000
# Iter 838 (Evals 41900): Nuevo Récord Global -> 0.0000000000
# Iter 840 (Evals 42000): Nuevo Récord Global -> 0.0000000000
# Iter 842 (Evals 42100): Nuevo Récord Global -> 0.0000000000
# Iter 843 (Evals 42150): Nuevo Récord Global -> 0.0000000000
# Iter 845 (Evals 42250): Nuevo Récord Global -> 0.0000000000
# Iter 846 (Evals 42300): Nuevo Récord Global -> 0.0000000000
# Iter 847 (Evals 42350): Nuevo Récord Global -> 0.0000000000
# Iter 849 (Evals 42450): Nuevo Récord Global -> 0.0000000000
# Iter 853 (Evals 42650): Nuevo Récord Global -> 0.0000000000
# Iter 854 (Evals 42700): Nuevo Récord Global -> 0.0000000000
# Iter 855 (Evals 42750): Nuevo Récord Global -> 0.0000000000
# Iter 857 (Evals 42850): Nuevo Récord Global -> 0.0000000000
# Iter 858 (Evals 42900): Nuevo Récord Global -> 0.0000000000
# Iter 859 (Evals 42950): Nuevo Récord Global -> 0.0000000000
# Iter 860 (Evals 43000): Nuevo Récord Global -> 0.0000000000
# Iter 861 (Evals 43050): Nuevo Récord Global -> 0.0000000000
# Iter 863 (Evals 43150): Nuevo Récord Global -> 0.0000000000
# Iter 865 (Evals 43250): Nuevo Récord Global -> 0.0000000000
# Iter 867 (Evals 43350): Nuevo Récord Global -> 0.0000000000
# Iter 868 (Evals 43400): Nuevo Récord Global -> 0.0000000000
# Iter 872 (Evals 43600): Nuevo Récord Global -> 0.0000000000
# Iter 873 (Evals 43650): Nuevo Récord Global -> 0.0000000000
# Iter 874 (Evals 43700): Nuevo Récord Global -> 0.0000000000
# Iter 875 (Evals 43750): Nuevo Récord Global -> 0.0000000000
# Iter 876 (Evals 43800): Nuevo Récord Global -> 0.0000000000
# Iter 877 (Evals 43850): Nuevo Récord Global -> 0.0000000000
# Iter 878 (Evals 43900): Nuevo Récord Global -> 0.0000000000
# Iter 879 (Evals 43950): Nuevo Récord Global -> 0.0000000000
# Iter 881 (Evals 44050): Nuevo Récord Global -> 0.0000000000
# Iter 882 (Evals 44100): Nuevo Récord Global -> 0.0000000000
# Iter 884 (Evals 44200): Nuevo Récord Global -> 0.0000000000
# Iter 885 (Evals 44250): Nuevo Récord Global -> 0.0000000000
# Iter 886 (Evals 44300): Nuevo Récord Global -> 0.0000000000
# Iter 887 (Evals 44350): Nuevo Récord Global -> 0.0000000000
# Iter 890 (Evals 44500): Nuevo Récord Global -> 0.0000000000
# Iter 891 (Evals 44550): Nuevo Récord Global -> 0.0000000000
# Iter 892 (Evals 44600): Nuevo Récord Global -> 0.0000000000
# Iter 893 (Evals 44650): Nuevo Récord Global -> 0.0000000000
# Iter 894 (Evals 44700): Nuevo Récord Global -> 0.0000000000
# Iter 896 (Evals 44800): Nuevo Récord Global -> 0.0000000000
# Iter 897 (Evals 44850): Nuevo Récord Global -> 0.0000000000
# Iter 898 (Evals 44900): Nuevo Récord Global -> 0.0000000000
# Iter 901 (Evals 45050): Nuevo Récord Global -> 0.0000000000
# Iter 902 (Evals 45100): Nuevo Récord Global -> 0.0000000000
# Iter 903 (Evals 45150): Nuevo Récord Global -> 0.0000000000
# Iter 904 (Evals 45200): Nuevo Récord Global -> 0.0000000000
# Iter 908 (Evals 45400): Nuevo Récord Global -> 0.0000000000
# Iter 909 (Evals 45450): Nuevo Récord Global -> 0.0000000000
# Iter 911 (Evals 45550): Nuevo Récord Global -> 0.0000000000
# Iter 915 (Evals 45750): Nuevo Récord Global -> 0.0000000000
# Iter 916 (Evals 45800): Nuevo Récord Global -> 0.0000000000
# Iter 917 (Evals 45850): Nuevo Récord Global -> 0.0000000000
# Iter 918 (Evals 45900): Nuevo Récord Global -> 0.0000000000
# Iter 919 (Evals 45950): Nuevo Récord Global -> 0.0000000000
# Iter 921 (Evals 46050): Nuevo Récord Global -> 0.0000000000
# Iter 922 (Evals 46100): Nuevo Récord Global -> 0.0000000000
# Iter 924 (Evals 46200): Nuevo Récord Global -> 0.0000000000
# Iter 925 (Evals 46250): Nuevo Récord Global -> 0.0000000000
# Iter 930 (Evals 46500): Nuevo Récord Global -> 0.0000000000
# Iter 931 (Evals 46550): Nuevo Récord Global -> 0.0000000000
# Iter 932 (Evals 46600): Nuevo Récord Global -> 0.0000000000
# Iter 934 (Evals 46700): Nuevo Récord Global -> 0.0000000000
# Iter 935 (Evals 46750): Nuevo Récord Global -> 0.0000000000
# Iter 938 (Evals 46900): Nuevo Récord Global -> 0.0000000000
# Iter 940 (Evals 47000): Nuevo Récord Global -> 0.0000000000
# Iter 941 (Evals 47050): Nuevo Récord Global -> 0.0000000000
# Iter 944 (Evals 47200): Nuevo Récord Global -> 0.0000000000
# Iter 946 (Evals 47300): Nuevo Récord Global -> 0.0000000000
# Iter 948 (Evals 47400): Nuevo Récord Global -> 0.0000000000
# Iter 951 (Evals 47550): Nuevo Récord Global -> 0.0000000000
# Iter 953 (Evals 47650): Nuevo Récord Global -> 0.0000000000
# Iter 958 (Evals 47900): Nuevo Récord Global -> 0.0000000000
# Iter 959 (Evals 47950): Nuevo Récord Global -> 0.0000000000
# Iter 961 (Evals 48050): Nuevo Récord Global -> 0.0000000000
# Iter 966 (Evals 48300): Nuevo Récord Global -> 0.0000000000
# Iter 967 (Evals 48350): Nuevo Récord Global -> 0.0000000000
# Iter 968 (Evals 48400): Nuevo Récord Global -> 0.0000000000
# Iter 969 (Evals 48450): Nuevo Récord Global -> 0.0000000000
# Iter 970 (Evals 48500): Nuevo Récord Global -> 0.0000000000
# Iter 971 (Evals 48550): Nuevo Récord Global -> 0.0000000000
# Iter 972 (Evals 48600): Nuevo Récord Global -> 0.0000000000
# Iter 977 (Evals 48850): Nuevo Récord Global -> 0.0000000000
# Iter 978 (Evals 48900): Nuevo Récord Global -> 0.0000000000
# Iter 980 (Evals 49000): Nuevo Récord Global -> 0.0000000000
# Iter 981 (Evals 49050): Nuevo Récord Global -> 0.0000000000
# Iter 982 (Evals 49100): Nuevo Récord Global -> 0.0000000000
# Iter 983 (Evals 49150): Nuevo Récord Global -> 0.0000000000
# Iter 985 (Evals 49250): Nuevo Récord Global -> 0.0000000000
# Iter 986 (Evals 49300): Nuevo Récord Global -> 0.0000000000
# Iter 987 (Evals 49350): Nuevo Récord Global -> 0.0000000000
# Iter 989 (Evals 49450): Nuevo Récord Global -> 0.0000000000
# Iter 990 (Evals 49500): Nuevo Récord Global -> 0.0000000000
# Iter 992 (Evals 49600): Nuevo Récord Global -> 0.0000000000
# Iter 993 (Evals 49650): Nuevo Récord Global -> 0.0000000000
# Iter 995 (Evals 49750): Nuevo Récord Global -> 0.0000000000
# Iter 997 (Evals 49850): Nuevo Récord Global -> 0.0000000000
# Iter 1000 (Evals 50000): Nuevo Récord Global -> 0.0000000000
# Iter 1001 (Evals 50050): Nuevo Récord Global -> 0.0000000000
# Iter 1002 (Evals 50100): Nuevo Récord Global -> 0.0000000000
# Iter 1003 (Evals 50150): Nuevo Récord Global -> 0.0000000000
# Iter 1006 (Evals 50300): Nuevo Récord Global -> 0.0000000000
# Iter 1007 (Evals 50350): Nuevo Récord Global -> 0.0000000000
# Iter 1009 (Evals 50450): Nuevo Récord Global -> 0.0000000000
# Iter 1010 (Evals 50500): Nuevo Récord Global -> 0.0000000000
# Iter 1011 (Evals 50550): Nuevo Récord Global -> 0.0000000000
# Iter 1012 (Evals 50600): Nuevo Récord Global -> 0.0000000000
# Iter 1016 (Evals 50800): Nuevo Récord Global -> 0.0000000000
# Iter 1017 (Evals 50850): Nuevo Récord Global -> 0.0000000000
# Iter 1018 (Evals 50900): Nuevo Récord Global -> 0.0000000000
# Iter 1019 (Evals 50950): Nuevo Récord Global -> 0.0000000000
# Iter 1021 (Evals 51050): Nuevo Récord Global -> 0.0000000000
# Iter 1024 (Evals 51200): Nuevo Récord Global -> 0.0000000000
# Iter 1026 (Evals 51300): Nuevo Récord Global -> 0.0000000000
# Iter 1027 (Evals 51350): Nuevo Récord Global -> 0.0000000000
# Iter 1028 (Evals 51400): Nuevo Récord Global -> 0.0000000000
# Iter 1030 (Evals 51500): Nuevo Récord Global -> 0.0000000000
# Iter 1033 (Evals 51650): Nuevo Récord Global -> 0.0000000000
# Iter 1034 (Evals 51700): Nuevo Récord Global -> 0.0000000000
# Iter 1035 (Evals 51750): Nuevo Récord Global -> 0.0000000000
# Iter 1039 (Evals 51950): Nuevo Récord Global -> 0.0000000000
# Iter 1043 (Evals 52150): Nuevo Récord Global -> 0.0000000000
# Iter 1045 (Evals 52250): Nuevo Récord Global -> 0.0000000000
# Iter 1046 (Evals 52300): Nuevo Récord Global -> 0.0000000000
# Iter 1047 (Evals 52350): Nuevo Récord Global -> 0.0000000000
# Iter 1049 (Evals 52450): Nuevo Récord Global -> 0.0000000000
# Iter 1051 (Evals 52550): Nuevo Récord Global -> 0.0000000000
# Iter 1052 (Evals 52600): Nuevo Récord Global -> 0.0000000000
# Iter 1053 (Evals 52650): Nuevo Récord Global -> 0.0000000000
# Iter 1054 (Evals 52700): Nuevo Récord Global -> 0.0000000000
# Iter 1058 (Evals 52900): Nuevo Récord Global -> 0.0000000000
# Iter 1059 (Evals 52950): Nuevo Récord Global -> 0.0000000000
# Iter 1060 (Evals 53000): Nuevo Récord Global -> 0.0000000000
# Iter 1061 (Evals 53050): Nuevo Récord Global -> 0.0000000000
# Iter 1063 (Evals 53150): Nuevo Récord Global -> 0.0000000000
# Iter 1064 (Evals 53200): Nuevo Récord Global -> 0.0000000000
# Iter 1065 (Evals 53250): Nuevo Récord Global -> 0.0000000000
# Iter 1066 (Evals 53300): Nuevo Récord Global -> 0.0000000000
# Iter 1067 (Evals 53350): Nuevo Récord Global -> 0.0000000000
# Iter 1069 (Evals 53450): Nuevo Récord Global -> 0.0000000000
# Iter 1070 (Evals 53500): Nuevo Récord Global -> 0.0000000000
# Iter 1071 (Evals 53550): Nuevo Récord Global -> 0.0000000000
# Iter 1074 (Evals 53700): Nuevo Récord Global -> 0.0000000000
# Iter 1076 (Evals 53800): Nuevo Récord Global -> 0.0000000000
# Iter 1080 (Evals 54000): Nuevo Récord Global -> 0.0000000000
# Iter 1081 (Evals 54050): Nuevo Récord Global -> 0.0000000000
# Iter 1082 (Evals 54100): Nuevo Récord Global -> 0.0000000000
# Iter 1084 (Evals 54200): Nuevo Récord Global -> 0.0000000000
# Iter 1088 (Evals 54400): Nuevo Récord Global -> 0.0000000000
# Iter 1089 (Evals 54450): Nuevo Récord Global -> 0.0000000000
# Iter 1093 (Evals 54650): Nuevo Récord Global -> 0.0000000000
# Iter 1095 (Evals 54750): Nuevo Récord Global -> 0.0000000000
# Iter 1096 (Evals 54800): Nuevo Récord Global -> 0.0000000000
# Iter 1097 (Evals 54850): Nuevo Récord Global -> 0.0000000000
# Iter 1099 (Evals 54950): Nuevo Récord Global -> 0.0000000000
# Iter 1101 (Evals 55050): Nuevo Récord Global -> 0.0000000000
# Iter 1102 (Evals 55100): Nuevo Récord Global -> 0.0000000000
# Iter 1103 (Evals 55150): Nuevo Récord Global -> 0.0000000000
# Iter 1104 (Evals 55200): Nuevo Récord Global -> 0.0000000000
# Iter 1105 (Evals 55250): Nuevo Récord Global -> 0.0000000000
# Iter 1109 (Evals 55450): Nuevo Récord Global -> 0.0000000000
# Iter 1111 (Evals 55550): Nuevo Récord Global -> 0.0000000000
# Iter 1113 (Evals 55650): Nuevo Récord Global -> 0.0000000000
# Iter 1115 (Evals 55750): Nuevo Récord Global -> 0.0000000000
# Iter 1116 (Evals 55800): Nuevo Récord Global -> 0.0000000000
# Iter 1118 (Evals 55900): Nuevo Récord Global -> 0.0000000000
# Iter 1120 (Evals 56000): Nuevo Récord Global -> 0.0000000000
# Iter 1124 (Evals 56200): Nuevo Récord Global -> 0.0000000000
# Iter 1126 (Evals 56300): Nuevo Récord Global -> 0.0000000000
# Iter 1128 (Evals 56400): Nuevo Récord Global -> 0.0000000000
# Iter 1130 (Evals 56500): Nuevo Récord Global -> 0.0000000000
# Iter 1132 (Evals 56600): Nuevo Récord Global -> 0.0000000000
# Iter 1133 (Evals 56650): Nuevo Récord Global -> 0.0000000000
# Iter 1136 (Evals 56800): Nuevo Récord Global -> 0.0000000000
# Iter 1138 (Evals 56900): Nuevo Récord Global -> 0.0000000000
# Iter 1139 (Evals 56950): Nuevo Récord Global -> 0.0000000000
# Iter 1140 (Evals 57000): Nuevo Récord Global -> 0.0000000000
# Iter 1143 (Evals 57150): Nuevo Récord Global -> 0.0000000000
# Iter 1144 (Evals 57200): Nuevo Récord Global -> 0.0000000000
# Iter 1146 (Evals 57300): Nuevo Récord Global -> 0.0000000000
# Iter 1147 (Evals 57350): Nuevo Récord Global -> 0.0000000000
# Iter 1148 (Evals 57400): Nuevo Récord Global -> 0.0000000000
# Iter 1149 (Evals 57450): Nuevo Récord Global -> 0.0000000000
# Iter 1151 (Evals 57550): Nuevo Récord Global -> 0.0000000000
# Iter 1155 (Evals 57750): Nuevo Récord Global -> 0.0000000000
# Iter 1156 (Evals 57800): Nuevo Récord Global -> 0.0000000000
# Iter 1159 (Evals 57950): Nuevo Récord Global -> 0.0000000000
# Iter 1162 (Evals 58100): Nuevo Récord Global -> 0.0000000000
# Iter 1163 (Evals 58150): Nuevo Récord Global -> 0.0000000000
# Iter 1164 (Evals 58200): Nuevo Récord Global -> 0.0000000000
# Iter 1165 (Evals 58250): Nuevo Récord Global -> 0.0000000000
# Iter 1166 (Evals 58300): Nuevo Récord Global -> 0.0000000000
# Iter 1167 (Evals 58350): Nuevo Récord Global -> 0.0000000000
# Iter 1168 (Evals 58400): Nuevo Récord Global -> 0.0000000000
# Iter 1170 (Evals 58500): Nuevo Récord Global -> 0.0000000000
# Iter 1172 (Evals 58600): Nuevo Récord Global -> 0.0000000000
# Iter 1176 (Evals 58800): Nuevo Récord Global -> 0.0000000000
# Iter 1177 (Evals 58850): Nuevo Récord Global -> 0.0000000000
# Iter 1180 (Evals 59000): Nuevo Récord Global -> 0.0000000000
# Iter 1182 (Evals 59100): Nuevo Récord Global -> 0.0000000000
# Iter 1183 (Evals 59150): Nuevo Récord Global -> 0.0000000000
# Iter 1185 (Evals 59250): Nuevo Récord Global -> 0.0000000000
# Iter 1186 (Evals 59300): Nuevo Récord Global -> 0.0000000000
# Iter 1187 (Evals 59350): Nuevo Récord Global -> 0.0000000000
# Iter 1188 (Evals 59400): Nuevo Récord Global -> 0.0000000000
# Iter 1191 (Evals 59550): Nuevo Récord Global -> 0.0000000000
# Iter 1192 (Evals 59600): Nuevo Récord Global -> 0.0000000000
# Iter 1195 (Evals 59750): Nuevo Récord Global -> 0.0000000000
# Iter 1196 (Evals 59800): Nuevo Récord Global -> 0.0000000000
# Iter 1199 (Evals 59950): Nuevo Récord Global -> 0.0000000000
# Iter 1200 (Evals 60000): Nuevo Récord Global -> 0.0000000000
# Iter 1201 (Evals 60050): Nuevo Récord Global -> 0.0000000000
# Iter 1205 (Evals 60250): Nuevo Récord Global -> 0.0000000000
# Iter 1207 (Evals 60350): Nuevo Récord Global -> 0.0000000000
# Iter 1209 (Evals 60450): Nuevo Récord Global -> 0.0000000000
# Iter 1210 (Evals 60500): Nuevo Récord Global -> 0.0000000000
# Iter 1211 (Evals 60550): Nuevo Récord Global -> 0.0000000000
# Iter 1212 (Evals 60600): Nuevo Récord Global -> 0.0000000000
# Iter 1214 (Evals 60700): Nuevo Récord Global -> 0.0000000000
# Iter 1218 (Evals 60900): Nuevo Récord Global -> 0.0000000000
# Iter 1220 (Evals 61000): Nuevo Récord Global -> 0.0000000000
# Iter 1221 (Evals 61050): Nuevo Récord Global -> 0.0000000000
# Iter 1223 (Evals 61150): Nuevo Récord Global -> 0.0000000000
# Iter 1225 (Evals 61250): Nuevo Récord Global -> 0.0000000000
# Iter 1227 (Evals 61350): Nuevo Récord Global -> 0.0000000000
# Iter 1230 (Evals 61500): Nuevo Récord Global -> 0.0000000000
# Iter 1233 (Evals 61650): Nuevo Récord Global -> 0.0000000000
# Iter 1236 (Evals 61800): Nuevo Récord Global -> 0.0000000000
# Iter 1237 (Evals 61850): Nuevo Récord Global -> 0.0000000000
# Iter 1238 (Evals 61900): Nuevo Récord Global -> 0.0000000000
# Iter 1239 (Evals 61950): Nuevo Récord Global -> 0.0000000000
# Iter 1243 (Evals 62150): Nuevo Récord Global -> 0.0000000000
# Iter 1244 (Evals 62200): Nuevo Récord Global -> 0.0000000000
# Iter 1245 (Evals 62250): Nuevo Récord Global -> 0.0000000000
# Iter 1246 (Evals 62300): Nuevo Récord Global -> 0.0000000000
# Iter 1247 (Evals 62350): Nuevo Récord Global -> 0.0000000000
# Iter 1248 (Evals 62400): Nuevo Récord Global -> 0.0000000000
# Iter 1249 (Evals 62450): Nuevo Récord Global -> 0.0000000000
# Iter 1250 (Evals 62500): Nuevo Récord Global -> 0.0000000000
# Iter 1251 (Evals 62550): Nuevo Récord Global -> 0.0000000000
# Iter 1252 (Evals 62600): Nuevo Récord Global -> 0.0000000000
# Iter 1254 (Evals 62700): Nuevo Récord Global -> 0.0000000000
# Iter 1255 (Evals 62750): Nuevo Récord Global -> 0.0000000000
# Iter 1256 (Evals 62800): Nuevo Récord Global -> 0.0000000000
# Iter 1257 (Evals 62850): Nuevo Récord Global -> 0.0000000000
# Iter 1258 (Evals 62900): Nuevo Récord Global -> 0.0000000000
# Iter 1259 (Evals 62950): Nuevo Récord Global -> 0.0000000000
# Iter 1260 (Evals 63000): Nuevo Récord Global -> 0.0000000000
# Iter 1262 (Evals 63100): Nuevo Récord Global -> 0.0000000000
# Iter 1264 (Evals 63200): Nuevo Récord Global -> 0.0000000000
# Iter 1265 (Evals 63250): Nuevo Récord Global -> 0.0000000000
# Iter 1268 (Evals 63400): Nuevo Récord Global -> 0.0000000000
# Iter 1270 (Evals 63500): Nuevo Récord Global -> 0.0000000000
# Iter 1273 (Evals 63650): Nuevo Récord Global -> 0.0000000000
# Iter 1274 (Evals 63700): Nuevo Récord Global -> 0.0000000000
# Iter 1276 (Evals 63800): Nuevo Récord Global -> 0.0000000000
# Iter 1277 (Evals 63850): Nuevo Récord Global -> 0.0000000000
# Iter 1279 (Evals 63950): Nuevo Récord Global -> 0.0000000000
# Iter 1283 (Evals 64150): Nuevo Récord Global -> 0.0000000000
# Iter 1284 (Evals 64200): Nuevo Récord Global -> 0.0000000000
# Iter 1285 (Evals 64250): Nuevo Récord Global -> 0.0000000000
# Iter 1286 (Evals 64300): Nuevo Récord Global -> 0.0000000000
# Iter 1288 (Evals 64400): Nuevo Récord Global -> 0.0000000000
# Iter 1290 (Evals 64500): Nuevo Récord Global -> 0.0000000000
# Iter 1293 (Evals 64650): Nuevo Récord Global -> 0.0000000000
# Iter 1295 (Evals 64750): Nuevo Récord Global -> 0.0000000000
# Iter 1297 (Evals 64850): Nuevo Récord Global -> 0.0000000000
# Iter 1299 (Evals 64950): Nuevo Récord Global -> 0.0000000000
# Iter 1300 (Evals 65000): Nuevo Récord Global -> 0.0000000000
# Iter 1302 (Evals 65100): Nuevo Récord Global -> 0.0000000000
# Iter 1305 (Evals 65250): Nuevo Récord Global -> 0.0000000000
# Iter 1306 (Evals 65300): Nuevo Récord Global -> 0.0000000000
# Iter 1308 (Evals 65400): Nuevo Récord Global -> 0.0000000000
# Iter 1309 (Evals 65450): Nuevo Récord Global -> 0.0000000000
# Iter 1313 (Evals 65650): Nuevo Récord Global -> 0.0000000000
# Iter 1314 (Evals 65700): Nuevo Récord Global -> 0.0000000000
# Iter 1316 (Evals 65800): Nuevo Récord Global -> 0.0000000000
# Iter 1317 (Evals 65850): Nuevo Récord Global -> 0.0000000000
# Iter 1318 (Evals 65900): Nuevo Récord Global -> 0.0000000000
# Iter 1322 (Evals 66100): Nuevo Récord Global -> 0.0000000000
# Iter 1324 (Evals 66200): Nuevo Récord Global -> 0.0000000000
# Iter 1325 (Evals 66250): Nuevo Récord Global -> 0.0000000000
# Iter 1328 (Evals 66400): Nuevo Récord Global -> 0.0000000000
# Iter 1329 (Evals 66450): Nuevo Récord Global -> 0.0000000000
# Iter 1333 (Evals 66650): Nuevo Récord Global -> 0.0000000000
# Iter 1334 (Evals 66700): Nuevo Récord Global -> 0.0000000000
# Iter 1335 (Evals 66750): Nuevo Récord Global -> 0.0000000000
# Iter 1338 (Evals 66900): Nuevo Récord Global -> 0.0000000000
# Iter 1339 (Evals 66950): Nuevo Récord Global -> 0.0000000000
# Iter 1340 (Evals 67000): Nuevo Récord Global -> 0.0000000000
# Iter 1341 (Evals 67050): Nuevo Récord Global -> 0.0000000000
# Iter 1343 (Evals 67150): Nuevo Récord Global -> 0.0000000000
# Iter 1344 (Evals 67200): Nuevo Récord Global -> 0.0000000000
# Iter 1347 (Evals 67350): Nuevo Récord Global -> 0.0000000000
# Iter 1348 (Evals 67400): Nuevo Récord Global -> 0.0000000000
# Iter 1349 (Evals 67450): Nuevo Récord Global -> 0.0000000000
# Iter 1350 (Evals 67500): Nuevo Récord Global -> 0.0000000000
# Iter 1351 (Evals 67550): Nuevo Récord Global -> 0.0000000000
# Iter 1352 (Evals 67600): Nuevo Récord Global -> 0.0000000000
# Iter 1353 (Evals 67650): Nuevo Récord Global -> 0.0000000000
# Iter 1354 (Evals 67700): Nuevo Récord Global -> 0.0000000000
# Iter 1356 (Evals 67800): Nuevo Récord Global -> 0.0000000000
# Iter 1357 (Evals 67850): Nuevo Récord Global -> 0.0000000000
# Iter 1360 (Evals 68000): Nuevo Récord Global -> 0.0000000000
# Iter 1361 (Evals 68050): Nuevo Récord Global -> 0.0000000000
# Iter 1364 (Evals 68200): Nuevo Récord Global -> 0.0000000000
# Iter 1366 (Evals 68300): Nuevo Récord Global -> 0.0000000000
# Iter 1368 (Evals 68400): Nuevo Récord Global -> 0.0000000000
# Iter 1369 (Evals 68450): Nuevo Récord Global -> 0.0000000000
# Iter 1370 (Evals 68500): Nuevo Récord Global -> 0.0000000000
# Iter 1371 (Evals 68550): Nuevo Récord Global -> 0.0000000000
# Iter 1373 (Evals 68650): Nuevo Récord Global -> 0.0000000000
# Iter 1375 (Evals 68750): Nuevo Récord Global -> 0.0000000000
# Iter 1376 (Evals 68800): Nuevo Récord Global -> 0.0000000000
# Iter 1377 (Evals 68850): Nuevo Récord Global -> 0.0000000000
# Iter 1379 (Evals 68950): Nuevo Récord Global -> 0.0000000000
# Iter 1380 (Evals 69000): Nuevo Récord Global -> 0.0000000000
# Iter 1382 (Evals 69100): Nuevo Récord Global -> 0.0000000000
# Iter 1384 (Evals 69200): Nuevo Récord Global -> 0.0000000000
# Iter 1385 (Evals 69250): Nuevo Récord Global -> 0.0000000000
# Iter 1389 (Evals 69450): Nuevo Récord Global -> 0.0000000000
# Iter 1390 (Evals 69500): Nuevo Récord Global -> 0.0000000000
# Iter 1391 (Evals 69550): Nuevo Récord Global -> 0.0000000000
# Iter 1392 (Evals 69600): Nuevo Récord Global -> 0.0000000000
# Iter 1393 (Evals 69650): Nuevo Récord Global -> 0.0000000000
# Iter 1394 (Evals 69700): Nuevo Récord Global -> 0.0000000000
# Iter 1395 (Evals 69750): Nuevo Récord Global -> 0.0000000000
# Iter 1396 (Evals 69800): Nuevo Récord Global -> 0.0000000000
# Iter 1397 (Evals 69850): Nuevo Récord Global -> 0.0000000000
# Iter 1398 (Evals 69900): Nuevo Récord Global -> 0.0000000000
# Iter 1399 (Evals 69950): Nuevo Récord Global -> 0.0000000000
# Iter 1400 (Evals 70000): Nuevo Récord Global -> 0.0000000000
# Iter 1402 (Evals 70100): Nuevo Récord Global -> 0.0000000000
# Iter 1404 (Evals 70200): Nuevo Récord Global -> 0.0000000000
# Iter 1405 (Evals 70250): Nuevo Récord Global -> 0.0000000000
# Iter 1408 (Evals 70400): Nuevo Récord Global -> 0.0000000000
# Iter 1411 (Evals 70550): Nuevo Récord Global -> 0.0000000000
# ...
# Iter 1549 (Evals 77450): Nuevo Récord Global -> 0.0000000000
# Iter 1553 (Evals 77650): Nuevo Récord Global -> 0.0000000000
# Iter 1554 (Evals 77700): Nuevo Récord Global -> 0.0000000000
# Iter 1555 (Evals 77750): Nuevo Récord Global -> 0.0000000000
# Iter 1557 (Evals 77850): Nuevo Récord Global -> 0.0000000000
# Iter 1558 (Evals 77900): Nuevo Récord Global -> 0.0000000000
# Iter 1559 (Evals 77950): Nuevo Récord Global -> 0.0000000000
# Iter 1561 (Evals 78050): Nuevo Récord Global -> 0.0000000000
# Iter 1563 (Evals 78150): Nuevo Récord Global -> 0.0000000000
# Iter 1565 (Evals 78250): Nuevo Récord Global -> 0.0000000000
# Iter 1573 (Evals 78650): Nuevo Récord Global -> 0.0000000000
# Iter 1574 (Evals 78700): Nuevo Récord Global -> 0.0000000000
# Iter 1575 (Evals 78750): Nuevo Récord Global -> 0.0000000000
# Iter 1576 (Evals 78800): Nuevo Récord Global -> 0.0000000000
# Iter 1578 (Evals 78900): Nuevo Récord Global -> 0.0000000000
# Iter 1580 (Evals 79000): Nuevo Récord Global -> 0.0000000000
# Iter 1583 (Evals 79150): Nuevo Récord Global -> 0.0000000000
# Iter 1586 (Evals 79300): Nuevo Récord Global -> 0.0000000000
# Iter 1587 (Evals 79350): Nuevo Récord Global -> 0.0000000000
# Iter 1589 (Evals 79450): Nuevo Récord Global -> 0.0000000000
# Iter 1590 (Evals 79500): Nuevo Récord Global -> 0.0000000000
# Iter 1592 (Evals 79600): Nuevo Récord Global -> 0.0000000000
# Iter 1598 (Evals 79900): Nuevo Récord Global -> 0.0000000000
# Iter 1599 (Evals 79950): Nuevo Récord Global -> 0.0000000000
# Iter 1601 (Evals 80050): Nuevo Récord Global -> 0.0000000000
# Iter 1602 (Evals 80100): Nuevo Récord Global -> 0.0000000000
# Iter 1603 (Evals 80150): Nuevo Récord Global -> 0.0000000000
# Iter 1604 (Evals 80200): Nuevo Récord Global -> 0.0000000000
# Iter 1606 (Evals 80300): Nuevo Récord Global -> 0.0000000000
# Iter 1607 (Evals 80350): Nuevo Récord Global -> 0.0000000000
# Iter 1609 (Evals 80450): Nuevo Récord Global -> 0.0000000000
# Iter 1610 (Evals 80500): Nuevo Récord Global -> 0.0000000000
# Iter 1611 (Evals 80550): Nuevo Récord Global -> 0.0000000000
# Iter 1612 (Evals 80600): Nuevo Récord Global -> 0.0000000000
# Iter 1613 (Evals 80650): Nuevo Récord Global -> 0.0000000000
# Iter 1614 (Evals 80700): Nuevo Récord Global -> 0.0000000000
# Iter 1616 (Evals 80800): Nuevo Récord Global -> 0.0000000000
# Iter 1617 (Evals 80850): Nuevo Récord Global -> 0.0000000000
# Iter 1618 (Evals 80900): Nuevo Récord Global -> 0.0000000000
# Iter 1619 (Evals 80950): Nuevo Récord Global -> 0.0000000000
# Iter 1620 (Evals 81000): Nuevo Récord Global -> 0.0000000000
# Iter 1622 (Evals 81100): Nuevo Récord Global -> 0.0000000000
# Iter 1624 (Evals 81200): Nuevo Récord Global -> 0.0000000000
# Iter 1625 (Evals 81250): Nuevo Récord Global -> 0.0000000000
# Iter 1626 (Evals 81300): Nuevo Récord Global -> 0.0000000000
# Iter 1629 (Evals 81450): Nuevo Récord Global -> 0.0000000000
# Iter 1630 (Evals 81500): Nuevo Récord Global -> 0.0000000000
# Iter 1634 (Evals 81700): Nuevo Récord Global -> 0.0000000000
# Iter 1638 (Evals 81900): Nuevo Récord Global -> 0.0000000000
# Iter 1639 (Evals 81950): Nuevo Récord Global -> 0.0000000000
# Iter 1640 (Evals 82000): Nuevo Récord Global -> 0.0000000000
# Iter 1641 (Evals 82050): Nuevo Récord Global -> 0.0000000000
# Iter 1643 (Evals 82150): Nuevo Récord Global -> 0.0000000000
# Iter 1644 (Evals 82200): Nuevo Récord Global -> 0.0000000000
# Iter 1645 (Evals 82250): Nuevo Récord Global -> 0.0000000000
# Iter 1647 (Evals 82350): Nuevo Récord Global -> 0.0000000000
# Iter 1648 (Evals 82400): Nuevo Récord Global -> 0.0000000000
# Iter 1649 (Evals 82450): Nuevo Récord Global -> 0.0000000000
# Iter 1652 (Evals 82600): Nuevo Récord Global -> 0.0000000000
# Iter 1653 (Evals 82650): Nuevo Récord Global -> 0.0000000000
# Iter 1654 (Evals 82700): Nuevo Récord Global -> 0.0000000000
# Iter 1657 (Evals 82850): Nuevo Récord Global -> 0.0000000000
# Iter 1659 (Evals 82950): Nuevo Récord Global -> 0.0000000000
# Iter 1662 (Evals 83100): Nuevo Récord Global -> 0.0000000000
# Iter 1664 (Evals 83200): Nuevo Récord Global -> 0.0000000000
# Iter 1665 (Evals 83250): Nuevo Récord Global -> 0.0000000000
# Iter 1667 (Evals 83350): Nuevo Récord Global -> 0.0000000000
# Iter 1668 (Evals 83400): Nuevo Récord Global -> 0.0000000000
# Iter 1670 (Evals 83500): Nuevo Récord Global -> 0.0000000000
# Iter 1674 (Evals 83700): Nuevo Récord Global -> 0.0000000000
# Iter 1676 (Evals 83800): Nuevo Récord Global -> 0.0000000000
# Iter 1677 (Evals 83850): Nuevo Récord Global -> 0.0000000000
# Iter 1678 (Evals 83900): Nuevo Récord Global -> 0.0000000000
# Iter 1681 (Evals 84050): Nuevo Récord Global -> 0.0000000000
# Iter 1682 (Evals 84100): Nuevo Récord Global -> 0.0000000000
# Iter 1683 (Evals 84150): Nuevo Récord Global -> 0.0000000000
# Iter 1684 (Evals 84200): Nuevo Récord Global -> 0.0000000000
# Iter 1689 (Evals 84450): Nuevo Récord Global -> 0.0000000000
# Iter 1690 (Evals 84500): Nuevo Récord Global -> 0.0000000000
# Iter 1693 (Evals 84650): Nuevo Récord Global -> 0.0000000000
# Iter 1694 (Evals 84700): Nuevo Récord Global -> 0.0000000000
# Iter 1696 (Evals 84800): Nuevo Récord Global -> 0.0000000000
# Iter 1697 (Evals 84850): Nuevo Récord Global -> 0.0000000000
# Iter 1700 (Evals 85000): Nuevo Récord Global -> 0.0000000000
# Iter 1702 (Evals 85100): Nuevo Récord Global -> 0.0000000000
# Iter 1703 (Evals 85150): Nuevo Récord Global -> 0.0000000000
# Iter 1704 (Evals 85200): Nuevo Récord Global -> 0.0000000000
# Iter 1705 (Evals 85250): Nuevo Récord Global -> 0.0000000000
# Iter 1706 (Evals 85300): Nuevo Récord Global -> 0.0000000000
# Iter 1707 (Evals 85350): Nuevo Récord Global -> 0.0000000000
# Iter 1710 (Evals 85500): Nuevo Récord Global -> 0.0000000000
# Iter 1712 (Evals 85600): Nuevo Récord Global -> 0.0000000000
# Iter 1713 (Evals 85650): Nuevo Récord Global -> 0.0000000000
# Iter 1714 (Evals 85700): Nuevo Récord Global -> 0.0000000000
# Iter 1715 (Evals 85750): Nuevo Récord Global -> 0.0000000000
# Iter 1717 (Evals 85850): Nuevo Récord Global -> 0.0000000000
# Iter 1718 (Evals 85900): Nuevo Récord Global -> 0.0000000000
# Iter 1719 (Evals 85950): Nuevo Récord Global -> 0.0000000000
# Iter 1721 (Evals 86050): Nuevo Récord Global -> 0.0000000000
# Iter 1722 (Evals 86100): Nuevo Récord Global -> 0.0000000000
# Iter 1723 (Evals 86150): Nuevo Récord Global -> 0.0000000000
# Iter 1724 (Evals 86200): Nuevo Récord Global -> 0.0000000000
# Iter 1726 (Evals 86300): Nuevo Récord Global -> 0.0000000000
# Iter 1729 (Evals 86450): Nuevo Récord Global -> 0.0000000000
# Iter 1730 (Evals 86500): Nuevo Récord Global -> 0.0000000000
# Iter 1731 (Evals 86550): Nuevo Récord Global -> 0.0000000000
# Iter 1736 (Evals 86800): Nuevo Récord Global -> 0.0000000000
# Iter 1738 (Evals 86900): Nuevo Récord Global -> 0.0000000000
# Iter 1739 (Evals 86950): Nuevo Récord Global -> 0.0000000000
# Iter 1740 (Evals 87000): Nuevo Récord Global -> 0.0000000000
# Iter 1743 (Evals 87150): Nuevo Récord Global -> 0.0000000000
# Iter 1745 (Evals 87250): Nuevo Récord Global -> 0.0000000000
# Iter 1747 (Evals 87350): Nuevo Récord Global -> 0.0000000000
# Iter 1748 (Evals 87400): Nuevo Récord Global -> 0.0000000000
# Iter 1749 (Evals 87450): Nuevo Récord Global -> 0.0000000000
# Iter 1750 (Evals 87500): Nuevo Récord Global -> 0.0000000000
# Iter 1751 (Evals 87550): Nuevo Récord Global -> 0.0000000000
# Iter 1752 (Evals 87600): Nuevo Récord Global -> 0.0000000000
# Iter 1753 (Evals 87650): Nuevo Récord Global -> 0.0000000000
# Iter 1754 (Evals 87700): Nuevo Récord Global -> 0.0000000000
# Iter 1756 (Evals 87800): Nuevo Récord Global -> 0.0000000000
# Iter 1757 (Evals 87850): Nuevo Récord Global -> 0.0000000000
# Iter 1759 (Evals 87950): Nuevo Récord Global -> 0.0000000000
# Iter 1761 (Evals 88050): Nuevo Récord Global -> 0.0000000000
# Iter 1765 (Evals 88250): Nuevo Récord Global -> 0.0000000000
# Iter 1766 (Evals 88300): Nuevo Récord Global -> 0.0000000000
# Iter 1767 (Evals 88350): Nuevo Récord Global -> 0.0000000000
# Iter 1768 (Evals 88400): Nuevo Récord Global -> 0.0000000000
# Iter 1772 (Evals 88600): Nuevo Récord Global -> 0.0000000000
# Iter 1773 (Evals 88650): Nuevo Récord Global -> 0.0000000000
# Iter 1775 (Evals 88750): Nuevo Récord Global -> 0.0000000000
# Iter 1777 (Evals 88850): Nuevo Récord Global -> 0.0000000000
# Iter 1778 (Evals 88900): Nuevo Récord Global -> 0.0000000000
# Iter 1779 (Evals 88950): Nuevo Récord Global -> 0.0000000000
# Iter 1780 (Evals 89000): Nuevo Récord Global -> 0.0000000000
# Iter 1781 (Evals 89050): Nuevo Récord Global -> 0.0000000000
# Iter 1782 (Evals 89100): Nuevo Récord Global -> 0.0000000000
# Iter 1783 (Evals 89150): Nuevo Récord Global -> 0.0000000000
# Iter 1786 (Evals 89300): Nuevo Récord Global -> 0.0000000000
# Iter 1788 (Evals 89400): Nuevo Récord Global -> 0.0000000000
# Iter 1792 (Evals 89600): Nuevo Récord Global -> 0.0000000000
# Iter 1793 (Evals 89650): Nuevo Récord Global -> 0.0000000000
# Iter 1795 (Evals 89750): Nuevo Récord Global -> 0.0000000000
# Iter 1796 (Evals 89800): Nuevo Récord Global -> 0.0000000000
# Iter 1797 (Evals 89850): Nuevo Récord Global -> 0.0000000000
# Iter 1799 (Evals 89950): Nuevo Récord Global -> 0.0000000000
# Iter 1800 (Evals 90000): Nuevo Récord Global -> 0.0000000000
# Iter 1801 (Evals 90050): Nuevo Récord Global -> 0.0000000000
# Iter 1802 (Evals 90100): Nuevo Récord Global -> 0.0000000000
# Iter 1803 (Evals 90150): Nuevo Récord Global -> 0.0000000000
# Iter 1804 (Evals 90200): Nuevo Récord Global -> 0.0000000000
# Iter 1808 (Evals 90400): Nuevo Récord Global -> 0.0000000000
# Iter 1812 (Evals 90600): Nuevo Récord Global -> 0.0000000000
# Iter 1813 (Evals 90650): Nuevo Récord Global -> 0.0000000000
# Iter 1819 (Evals 90950): Nuevo Récord Global -> 0.0000000000
# Iter 1820 (Evals 91000): Nuevo Récord Global -> 0.0000000000
# Iter 1825 (Evals 91250): Nuevo Récord Global -> 0.0000000000
# Iter 1829 (Evals 91450): Nuevo Récord Global -> 0.0000000000
# Iter 1834 (Evals 91700): Nuevo Récord Global -> 0.0000000000
# Iter 1835 (Evals 91750): Nuevo Récord Global -> 0.0000000000
# Iter 1836 (Evals 91800): Nuevo Récord Global -> 0.0000000000
# Iter 1837 (Evals 91850): Nuevo Récord Global -> 0.0000000000
# Iter 1838 (Evals 91900): Nuevo Récord Global -> 0.0000000000
# Iter 1841 (Evals 92050): Nuevo Récord Global -> 0.0000000000
# Iter 1842 (Evals 92100): Nuevo Récord Global -> 0.0000000000
# Iter 1845 (Evals 92250): Nuevo Récord Global -> 0.0000000000
# Iter 1846 (Evals 92300): Nuevo Récord Global -> 0.0000000000
# Iter 1847 (Evals 92350): Nuevo Récord Global -> 0.0000000000
# Iter 1852 (Evals 92600): Nuevo Récord Global -> 0.0000000000
# Iter 1854 (Evals 92700): Nuevo Récord Global -> 0.0000000000
# Iter 1856 (Evals 92800): Nuevo Récord Global -> 0.0000000000
# Iter 1858 (Evals 92900): Nuevo Récord Global -> 0.0000000000
# Iter 1861 (Evals 93050): Nuevo Récord Global -> 0.0000000000
# Iter 1862 (Evals 93100): Nuevo Récord Global -> 0.0000000000
# Iter 1864 (Evals 93200): Nuevo Récord Global -> 0.0000000000
# Iter 1865 (Evals 93250): Nuevo Récord Global -> 0.0000000000
# Iter 1867 (Evals 93350): Nuevo Récord Global -> 0.0000000000
# Iter 1868 (Evals 93400): Nuevo Récord Global -> 0.0000000000
# Iter 1870 (Evals 93500): Nuevo Récord Global -> 0.0000000000
# Iter 1872 (Evals 93600): Nuevo Récord Global -> 0.0000000000
# Iter 1874 (Evals 93700): Nuevo Récord Global -> 0.0000000000
# Iter 1875 (Evals 93750): Nuevo Récord Global -> 0.0000000000
# Iter 1878 (Evals 93900): Nuevo Récord Global -> 0.0000000000
# Iter 1881 (Evals 94050): Nuevo Récord Global -> 0.0000000000
# Iter 1882 (Evals 94100): Nuevo Récord Global -> 0.0000000000
# Iter 1883 (Evals 94150): Nuevo Récord Global -> 0.0000000000
# Iter 1884 (Evals 94200): Nuevo Récord Global -> 0.0000000000
# Iter 1885 (Evals 94250): Nuevo Récord Global -> 0.0000000000
# Iter 1887 (Evals 94350): Nuevo Récord Global -> 0.0000000000
# Iter 1888 (Evals 94400): Nuevo Récord Global -> 0.0000000000
# Iter 1889 (Evals 94450): Nuevo Récord Global -> 0.0000000000
# Iter 1890 (Evals 94500): Nuevo Récord Global -> 0.0000000000
# Iter 1892 (Evals 94600): Nuevo Récord Global -> 0.0000000000
# Iter 1893 (Evals 94650): Nuevo Récord Global -> 0.0000000000
# Iter 1895 (Evals 94750): Nuevo Récord Global -> 0.0000000000
# Iter 1896 (Evals 94800): Nuevo Récord Global -> 0.0000000000
# Iter 1899 (Evals 94950): Nuevo Récord Global -> 0.0000000000
# Iter 1901 (Evals 95050): Nuevo Récord Global -> 0.0000000000
# Iter 1902 (Evals 95100): Nuevo Récord Global -> 0.0000000000
# Iter 1903 (Evals 95150): Nuevo Récord Global -> 0.0000000000
# Iter 1904 (Evals 95200): Nuevo Récord Global -> 0.0000000000
# Iter 1907 (Evals 95350): Nuevo Récord Global -> 0.0000000000
# Iter 1908 (Evals 95400): Nuevo Récord Global -> 0.0000000000
# Iter 1911 (Evals 95550): Nuevo Récord Global -> 0.0000000000
# Iter 1912 (Evals 95600): Nuevo Récord Global -> 0.0000000000
# Iter 1913 (Evals 95650): Nuevo Récord Global -> 0.0000000000
# Iter 1916 (Evals 95800): Nuevo Récord Global -> 0.0000000000
# Iter 1917 (Evals 95850): Nuevo Récord Global -> 0.0000000000
# Iter 1920 (Evals 96000): Nuevo Récord Global -> 0.0000000000
# Iter 1922 (Evals 96100): Nuevo Récord Global -> 0.0000000000
# Iter 1923 (Evals 96150): Nuevo Récord Global -> 0.0000000000
# Iter 1924 (Evals 96200): Nuevo Récord Global -> 0.0000000000
# Iter 1925 (Evals 96250): Nuevo Récord Global -> 0.0000000000
# Iter 1928 (Evals 96400): Nuevo Récord Global -> 0.0000000000
# Iter 1931 (Evals 96550): Nuevo Récord Global -> 0.0000000000
# Iter 1933 (Evals 96650): Nuevo Récord Global -> 0.0000000000
# Iter 1935 (Evals 96750): Nuevo Récord Global -> 0.0000000000
# Iter 1936 (Evals 96800): Nuevo Récord Global -> 0.0000000000
# Iter 1938 (Evals 96900): Nuevo Récord Global -> 0.0000000000
# Iter 1939 (Evals 96950): Nuevo Récord Global -> 0.0000000000
# Iter 1941 (Evals 97050): Nuevo Récord Global -> 0.0000000000
# Iter 1943 (Evals 97150): Nuevo Récord Global -> 0.0000000000
# Iter 1944 (Evals 97200): Nuevo Récord Global -> 0.0000000000
# Iter 1945 (Evals 97250): Nuevo Récord Global -> 0.0000000000
# Iter 1948 (Evals 97400): Nuevo Récord Global -> 0.0000000000
# Iter 1950 (Evals 97500): Nuevo Récord Global -> 0.0000000000
# Iter 1951 (Evals 97550): Nuevo Récord Global -> 0.0000000000
# Iter 1952 (Evals 97600): Nuevo Récord Global -> 0.0000000000
# Iter 1953 (Evals 97650): Nuevo Récord Global -> 0.0000000000
# Iter 1954 (Evals 97700): Nuevo Récord Global -> 0.0000000000
# Iter 1955 (Evals 97750): Nuevo Récord Global -> 0.0000000000
# Iter 1957 (Evals 97850): Nuevo Récord Global -> 0.0000000000
# Iter 1958 (Evals 97900): Nuevo Récord Global -> 0.0000000000
# Iter 1960 (Evals 98000): Nuevo Récord Global -> 0.0000000000
# Iter 1961 (Evals 98050): Nuevo Récord Global -> 0.0000000000
# Iter 1962 (Evals 98100): Nuevo Récord Global -> 0.0000000000
# Iter 1963 (Evals 98150): Nuevo Récord Global -> 0.0000000000
# Iter 1966 (Evals 98300): Nuevo Récord Global -> 0.0000000000
# Iter 1967 (Evals 98350): Nuevo Récord Global -> 0.0000000000
# Iter 1968 (Evals 98400): Nuevo Récord Global -> 0.0000000000
# Iter 1970 (Evals 98500): Nuevo Récord Global -> 0.0000000000
# Iter 1971 (Evals 98550): Nuevo Récord Global -> 0.0000000000
# Iter 1972 (Evals 98600): Nuevo Récord Global -> 0.0000000000
# Iter 1973 (Evals 98650): Nuevo Récord Global -> 0.0000000000
# Iter 1975 (Evals 98750): Nuevo Récord Global -> 0.0000000000
# Iter 1976 (Evals 98800): Nuevo Récord Global -> 0.0000000000
# Iter 1978 (Evals 98900): Nuevo Récord Global -> 0.0000000000
# Iter 1979 (Evals 98950): Nuevo Récord Global -> 0.0000000000
# Iter 1980 (Evals 99000): Nuevo Récord Global -> 0.0000000000
# Iter 1983 (Evals 99150): Nuevo Récord Global -> 0.0000000000
# Iter 1984 (Evals 99200): Nuevo Récord Global -> 0.0000000000
# Iter 1986 (Evals 99300): Nuevo Récord Global -> 0.0000000000
# Iter 1987 (Evals 99350): Nuevo Récord Global -> 0.0000000000
# Iter 1988 (Evals 99400): Nuevo Récord Global -> 0.0000000000
# Iter 1990 (Evals 99500): Nuevo Récord Global -> 0.0000000000
# Iter 1991 (Evals 99550): Nuevo Récord Global -> 0.0000000000
# Iter 1992 (Evals 99600): Nuevo Récord Global -> 0.0000000000
# Iter 1993 (Evals 99650): Nuevo Récord Global -> 0.0000000000
# Iter 1996 (Evals 99800): Nuevo Récord Global -> 0.0000000000
# Iter 1997 (Evals 99850): Nuevo Récord Global -> 0.0000000000
# Iter 1999 (Evals 99950): Nuevo Récord Global -> 0.0000000000
#
# Resultado final (debe ser cercano a 0): 1.6381993136343745e-124
